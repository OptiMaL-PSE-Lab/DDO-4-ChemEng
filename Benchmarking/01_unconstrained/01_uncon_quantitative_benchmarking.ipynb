# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *
from ENTMOOT import *


##########################
# Algorithms & Functions #
##########################

home_dir  = 'images/trajectory_plots_1D_&_tables'

algorithms_test = [
    LS_QM_v2,
    opt_SnobFit,
    opt_SRBF,
    opt_DYCORS,
    opt_SOP,
    opt_COBYLA,
    COBYQA,
    opt_CUATRO,
# # # Feel free to add these commented-out algorithms as a further test,
# # # however, do note they are more time-consuming to run
BO_np_scipy,
opt_ENTMOOT,
]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    5,
    7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 1                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    50,
    100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

# %% [markdown]
# ### Benchmark

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  Levy_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB4A83FCD0>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# ==  opt_CUATRO
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 2, objective 2.626, evaluation 13
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-22
# Set parameter MIPGap to value 0
# 4.740456010170977
# Set parameter MIPGap to value 0
# 7.8999098757940756
# Set parameter MIPGap to value 0
# 1.9960623472853347
# Set parameter MIPGap to value 0
# 1.0612153635967967
# Set parameter MIPGap to value 0
# 1.6406656137527453
# Set parameter MIPGap to value 0
# 1.4688689102134826
# Set parameter MIPGap to value 0
# 1.5911063171420086
# Set parameter MIPGap to value 0
# 2.7093673934348717
# Set parameter MIPGap to value 0
# 2.1384804335241845
# Set parameter MIPGap to value 0
# 0.25803388020782275
# Set parameter MIPGap to value 0
# 0.004643676571233709
# Set parameter MIPGap to value 0
# 0.5149076635234602
# Set parameter MIPGap to value 0
# 0.6975490968317979
# Set parameter MIPGap to value 0
# 0.12390706025262653
# Set parameter MIPGap to value 0
# 0.3594903014041292
# Set parameter MIPGap to value 0
# 0.35759579206385156
# Set parameter MIPGap to value 0
# 0.08355108492939672
# Set parameter MIPGap to value 0
# 0.021592300955679326
# Set parameter MIPGap to value 0
# 0.04887672770486479
# Set parameter MIPGap to value 0
# 0.055539833370661144
# =====================  Ackley_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB4A8F0710>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# ==  opt_CUATRO
# TR update: iteration 1, objective 0.287, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 13.41993567757193
# Set parameter MIPGap to value 0
# 8.306934424580634
# Set parameter MIPGap to value 0
# 4.480872976411888
# Set parameter MIPGap to value 0
# 11.567542603019643
# Set parameter MIPGap to value 0
# 7.070339064702781
# Set parameter MIPGap to value 0
# 7.629665648566142
# Set parameter MIPGap to value 0
# 6.191581854429121
# Set parameter MIPGap to value 0
# 6.117098835678227
# Set parameter MIPGap to value 0
# 4.274904562556074
# Set parameter MIPGap to value 0
# 2.973985437797005
# Set parameter MIPGap to value 0
# 5.1606774232482415
# Set parameter MIPGap to value 0
# 3.9038112676901275
# Set parameter MIPGap to value 0
# 4.356502978045864
# Set parameter MIPGap to value 0
# 2.8957476231596684
# Set parameter MIPGap to value 0
# 3.6150070272804915
# Set parameter MIPGap to value 0
# 4.344284151076753
# Set parameter MIPGap to value 0
# 3.117276763432621
# Set parameter MIPGap to value 0
# 2.9188509373754816
# Set parameter MIPGap to value 0
# 3.33072632984667
# Set parameter MIPGap to value 0
# 2.5881380470708675
# =====================  Rosenbrock_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DC08250>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# ==  opt_CUATRO
# TR update: iteration 2, objective 2.361, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 2660.4363348227416
# Set parameter MIPGap to value 0
# 798.3194315704817
# Set parameter MIPGap to value 0
# 26442.75456463527
# Set parameter MIPGap to value 0
# 6906.006026786526
# Set parameter MIPGap to value 0
# 1749.5617641629026
# Set parameter MIPGap to value 0
# 99.82007441610267
# Set parameter MIPGap to value 0
# 76.53751898914444
# Set parameter MIPGap to value 0
# 3100.1987730987335
# Set parameter MIPGap to value 0
# 1688.3280937832674
# Set parameter MIPGap to value 0
# 3597.1915800159136
# Set parameter MIPGap to value 0
# 12.069518646594668
# Set parameter MIPGap to value 0
# 1205.5639452557295
# Set parameter MIPGap to value 0
# 245.23240482955703
# Set parameter MIPGap to value 0
# 364.24729962100866
# Set parameter MIPGap to value 0
# 228.28527710934986
# Set parameter MIPGap to value 0
# 1591.791120480555
# Set parameter MIPGap to value 0
# 122.76875001737486
# Set parameter MIPGap to value 0
# 18.17408416219444
# Set parameter MIPGap to value 0
# 41.659753458857594
# Set parameter MIPGap to value 0
# 9.401233041099433
# =====================  Antonio_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DB50BD0>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# ==  opt_CUATRO
# TR update: iteration 1, objective 0.000, evaluation 7
# TR update: iteration 2, objective 0.000, evaluation 12
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 52.12984736557691
# Set parameter MIPGap to value 0
# 207.51455710342142
# Set parameter MIPGap to value 0
# 5.609006770701359
# Set parameter MIPGap to value 0
# 51.906083382926674
# Set parameter MIPGap to value 0
# 24.09868344583584
# Set parameter MIPGap to value 0
# 14.199139081329301
# Set parameter MIPGap to value 0
# 15.412149907609106
# Set parameter MIPGap to value 0
# 26.06545962954852
# Set parameter MIPGap to value 0
# 11.618324948047956
# Set parameter MIPGap to value 0
# 8.931862982516956
# Set parameter MIPGap to value 0
# 17.273159432867637
# Set parameter MIPGap to value 0
# 8.812482652152976
# Set parameter MIPGap to value 0
# 7.9166103013603735
# Set parameter MIPGap to value 0
# 12.030423341067689
# Set parameter MIPGap to value 0
# 27.698883287790714
# Set parameter MIPGap to value 0
# 6.7580823877346
# Set parameter MIPGap to value 0
# 6.4878528681511165
# Set parameter MIPGap to value 0
# 5.913363739981802
# Set parameter MIPGap to value 0
# 7.7158356073755225
# Set parameter MIPGap to value 0
# 10.876339498993733
# =====================  Levy_f D5
# ==  LS_QM_v2
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DC0E350>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 1, objective 9.400, evaluation 7
# TR update: iteration 2, objective 6.682, evaluation 12
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 5, objective 4.006, evaluation 29
# TR update: iteration 6, objective 3.087, evaluation 33
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 43.237576422138844
# Set parameter MIPGap to value 0
# 20.879445158917243
# Set parameter MIPGap to value 0
# 26.764242353415174
# Set parameter MIPGap to value 0
# 16.72147816210782
# Set parameter MIPGap to value 0
# 7.922701830398595
# Set parameter MIPGap to value 0
# 0.7225779986491634
# Set parameter MIPGap to value 0
# 18.792470400666684
# Set parameter MIPGap to value 0
# 2.0836600919240675
# Set parameter MIPGap to value 0
# 2.512768762308955
# Set parameter MIPGap to value 0
# 9.896217505672022
# Set parameter MIPGap to value 0
# 4.343814390282697
# Set parameter MIPGap to value 0
# 1.7933140072705518
# Set parameter MIPGap to value 0
# 0.8645935252299815
# Set parameter MIPGap to value 0
# 10.151878940221378
# Set parameter MIPGap to value 0
# 9.08268111130676
# Set parameter MIPGap to value 0
# 1.2610965762511492
# Set parameter MIPGap to value 0
# 0.9386525289074185
# Set parameter MIPGap to value 0
# 1.8308475556433648
# Set parameter MIPGap to value 0
# 0.7030036199004169
# Set parameter MIPGap to value 0
# 0.5485920280631194
# Set parameter MIPGap to value 0
# 1.3446042366138486
# Set parameter MIPGap to value 0
# 1.6219066438854324
# Set parameter MIPGap to value 0
# 2.1457850831733665
# Set parameter MIPGap to value 0
# 1.1957083928938963
# Set parameter MIPGap to value 0
# 3.3422802073250133
# Set parameter MIPGap to value 0
# 0.16499548782996076
# Set parameter MIPGap to value 0
# 0.9995720891427616
# Set parameter MIPGap to value 0
# 0.2101187851382581
# Set parameter MIPGap to value 0
# 0.4460318746819167
# Set parameter MIPGap to value 0
# 0.2450195499895293
# Set parameter MIPGap to value 0
# 0.1887741866091845
# Set parameter MIPGap to value 0
# 0.805405956296155
# Set parameter MIPGap to value 0
# 0.9398069731809031
# Set parameter MIPGap to value 0
# 2.2158381666228624
# Set parameter MIPGap to value 0
# 12.704884569454219
# Set parameter MIPGap to value 0
# 0.7396066940244524
# Set parameter MIPGap to value 0
# 0.6895780260372797
# Set parameter MIPGap to value 0
# 0.3547399466323387
# Set parameter MIPGap to value 0
# 1.4737983373713641
# Set parameter MIPGap to value 0
# 0.9737265643408088
# Set parameter MIPGap to value 0
# 0.3176913223987691
# Set parameter MIPGap to value 0
# 0.3720594717019545
# Set parameter MIPGap to value 0
# 0.6989078789531653
# Set parameter MIPGap to value 0
# 2.5382456528077575
# Set parameter MIPGap to value 0
# 0.11547132942839615
# Set parameter MIPGap to value 0
# 0.5133189238566003
# Set parameter MIPGap to value 0
# 1.1666727183848873
# Set parameter MIPGap to value 0
# 0.7146480550428898
# Set parameter MIPGap to value 0
# 1.4721116605406948
# Set parameter MIPGap to value 0
# 0.5762634037027572
# =====================  Ackley_f D5
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DB4D490>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 1, objective 9.872, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 14.788464798573798
# Set parameter MIPGap to value 0
# 17.506874008023548
# Set parameter MIPGap to value 0
# 16.06289897176027
# Set parameter MIPGap to value 0
# 14.634483674350605
# Set parameter MIPGap to value 0
# 13.035873067388865
# Set parameter MIPGap to value 0
# 8.649810734453649
# Set parameter MIPGap to value 0
# 14.7227418936358
# Set parameter MIPGap to value 0
# 10.23456455121847
# Set parameter MIPGap to value 0
# 10.122222272626912
# Set parameter MIPGap to value 0
# 13.557760341169457
# Set parameter MIPGap to value 0
# 11.509598700614825
# Set parameter MIPGap to value 0
# 9.032647732832688
# Set parameter MIPGap to value 0
# 10.042376321374418
# Set parameter MIPGap to value 0
# 14.053833212540964
# Set parameter MIPGap to value 0
# 10.004355677926739
# Set parameter MIPGap to value 0
# 7.041916722701281
# Set parameter MIPGap to value 0
# 10.499416017241602
# Set parameter MIPGap to value 0
# 9.933343588737161
# Set parameter MIPGap to value 0
# 8.227479720681487
# Set parameter MIPGap to value 0
# 4.191498668838637
# Set parameter MIPGap to value 0
# 7.893515790646573
# Set parameter MIPGap to value 0
# 7.981792911853306
# Set parameter MIPGap to value 0
# 7.229109765405603
# Set parameter MIPGap to value 0
# 6.653123179229198
# Set parameter MIPGap to value 0
# 11.650844854436322
# Set parameter MIPGap to value 0
# 5.753777203805132
# Set parameter MIPGap to value 0
# 6.673807184407039
# Set parameter MIPGap to value 0
# 4.784550554802461
# Set parameter MIPGap to value 0
# 4.585963843546317
# Set parameter MIPGap to value 0
# 6.161297247240135
# Set parameter MIPGap to value 0
# 4.202820840613047
# Set parameter MIPGap to value 0
# 8.260381310704364
# Set parameter MIPGap to value 0
# 5.772468976526856
# Set parameter MIPGap to value 0
# 4.478433313253483
# Set parameter MIPGap to value 0
# 3.9011823455021823
# Set parameter MIPGap to value 0
# 4.485426322385887
# Set parameter MIPGap to value 0
# 4.5041314135390955
# Set parameter MIPGap to value 0
# 4.863925830629995
# Set parameter MIPGap to value 0
# 3.2901713140621998
# Set parameter MIPGap to value 0
# 4.701660652667673
# Set parameter MIPGap to value 0
# 4.854244887831484
# Set parameter MIPGap to value 0
# 3.3375703843885103
# Set parameter MIPGap to value 0
# 3.8051825760125806
# Set parameter MIPGap to value 0
# 4.226044555589741
# Set parameter MIPGap to value 0
# 4.101951035062861
# Set parameter MIPGap to value 0
# 3.538198360111306
# Set parameter MIPGap to value 0
# 5.064182214826463
# Set parameter MIPGap to value 0
# 3.5850318746536947
# Set parameter MIPGap to value 0
# 3.7514852863311146
# Set parameter MIPGap to value 0
# 4.426129407757493
# =====================  Rosenbrock_f D5
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9FCFFA90>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 2, objective 10032.655, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 3, objective 4785.973, evaluation 19
# TR update: iteration 4, objective 1857.664, evaluation 22
# TR update: iteration 5, objective 1538.053, evaluation 28
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 309290.17497930006
# Set parameter MIPGap to value 0
# 220694.58793294002
# Set parameter MIPGap to value 0
# 781121.5690111587
# Set parameter MIPGap to value 0
# 139193.66822856193
# Set parameter MIPGap to value 0
# 29193.267935678185
# Set parameter MIPGap to value 0
# 374642.6663512114
# Set parameter MIPGap to value 0
# 47016.521898059946
# Set parameter MIPGap to value 0
# 33504.20249554644
# Set parameter MIPGap to value 0
# 81478.38572849408
# Set parameter MIPGap to value 0
# 92287.69749837578
# Set parameter MIPGap to value 0
# 90136.16002987254
# Set parameter MIPGap to value 0
# 49652.112989925
# Set parameter MIPGap to value 0
# 25668.888769795998
# Set parameter MIPGap to value 0
# 41896.10865107383
# Set parameter MIPGap to value 0
# 15042.831855650189
# Set parameter MIPGap to value 0
# 618.4440575973771
# Set parameter MIPGap to value 0
# 77191.23771022672
# Set parameter MIPGap to value 0
# 13171.408859791774
# Set parameter MIPGap to value 0
# 2144.422126834742
# Set parameter MIPGap to value 0
# 4175.062403053745
# Set parameter MIPGap to value 0
# 2599.2867353770616
# Set parameter MIPGap to value 0
# 425.28661343152237
# Set parameter MIPGap to value 0
# 1965.1711547534624
# Set parameter MIPGap to value 0
# 5144.018406981055
# Set parameter MIPGap to value 0
# 960.9993190036496
# Set parameter MIPGap to value 0
# 9463.749164206049
# Set parameter MIPGap to value 0
# 1420.5146034422862
# Set parameter MIPGap to value 0
# 3268.0683214306996
# Set parameter MIPGap to value 0
# 1836.2926860187365
# Set parameter MIPGap to value 0
# 3222.338204614681
# Set parameter MIPGap to value 0
# 4337.673749768059
# Set parameter MIPGap to value 0
# 4969.52743602684
# Set parameter MIPGap to value 0
# 2782.2553726493566
# Set parameter MIPGap to value 0
# 1332.667587494536
# Set parameter MIPGap to value 0
# 2410.120846983373
# Set parameter MIPGap to value 0
# 828.8758246359174
# Set parameter MIPGap to value 0
# 2872.2840723858935
# Set parameter MIPGap to value 0
# 3801.545093871075
# Set parameter MIPGap to value 0
# 4681.147632830098
# Set parameter MIPGap to value 0
# 2463.1730725995976
# Set parameter MIPGap to value 0
# 3549.799057980054
# Set parameter MIPGap to value 0
# 3656.222395558049
# Set parameter MIPGap to value 0
# 790.566507078189
# Set parameter MIPGap to value 0
# 1757.8112110247864
# Set parameter MIPGap to value 0
# 1885.9126576673443
# Set parameter MIPGap to value 0
# 2252.2632879119747
# Set parameter MIPGap to value 0
# 3413.7081963426313
# Set parameter MIPGap to value 0
# 1512.9866970587364
# Set parameter MIPGap to value 0
# 4420.987803347874
# Set parameter MIPGap to value 0
# 3884.3844884556715
# =====================  Antonio_f D5
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DB5A790>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 2, objective 2306.800, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 3, objective 1819.583, evaluation 18
# TR update: iteration 4, objective 1367.289, evaluation 24
# TR update: iteration 5, objective 1036.818, evaluation 28
# TR update: iteration 6, objective 745.919, evaluation 33
# TR update: iteration 7, objective 547.104, evaluation 38
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 9207.184537793062
# Set parameter MIPGap to value 0
# 10652.182393158679
# Set parameter MIPGap to value 0
# 8835.810880524052
# Set parameter MIPGap to value 0
# 4470.623579987023
# Set parameter MIPGap to value 0
# 4971.537985086772
# Set parameter MIPGap to value 0
# 4516.16512291756
# Set parameter MIPGap to value 0
# 423.846561146878
# Set parameter MIPGap to value 0
# 2300.555358566025
# Set parameter MIPGap to value 0
# 2899.078054727145
# Set parameter MIPGap to value 0
# 5362.596035409826
# Set parameter MIPGap to value 0
# 1285.3558374423508
# Set parameter MIPGap to value 0
# 1925.1069856239426
# Set parameter MIPGap to value 0
# 516.909523988468
# Set parameter MIPGap to value 0
# 1099.1844704386708
# Set parameter MIPGap to value 0
# 882.4236868326291
# Set parameter MIPGap to value 0
# 955.2992854330097
# Set parameter MIPGap to value 0
# 1085.456963489137
# Set parameter MIPGap to value 0
# 738.3412189017287
# Set parameter MIPGap to value 0
# 127.93906466852599
# Set parameter MIPGap to value 0
# 323.81465082874996
# Set parameter MIPGap to value 0
# 453.84770259023935
# Set parameter MIPGap to value 0
# 417.31265020034044
# Set parameter MIPGap to value 0
# 539.4554539016519
# Set parameter MIPGap to value 0
# 881.0516511153852
# Set parameter MIPGap to value 0
# 624.554747698299
# Set parameter MIPGap to value 0
# 74.99319135356222
# Set parameter MIPGap to value 0
# 319.2133814471805
# Set parameter MIPGap to value 0
# 200.51876779331928
# Set parameter MIPGap to value 0
# 490.0803393873325
# Set parameter MIPGap to value 0
# 1056.0587290443905
# Set parameter MIPGap to value 0
# 139.3621532938517
# Set parameter MIPGap to value 0
# 320.31590011441614
# Set parameter MIPGap to value 0
# 88.46692227091927
# Set parameter MIPGap to value 0
# 1228.9616234724576
# Set parameter MIPGap to value 0
# 165.6082298152242
# Set parameter MIPGap to value 0
# 1027.8651375461168
# Set parameter MIPGap to value 0
# 149.3714186716128
# Set parameter MIPGap to value 0
# 565.2011646671632
# Set parameter MIPGap to value 0
# 519.4666254036167
# Set parameter MIPGap to value 0
# 657.3013456319244
# Set parameter MIPGap to value 0
# 40.493890016213975
# Set parameter MIPGap to value 0
# 122.47084975337951
# Set parameter MIPGap to value 0
# 216.45717800768767
# Set parameter MIPGap to value 0
# 133.32511623424082
# Set parameter MIPGap to value 0
# 357.9328978890807
# Set parameter MIPGap to value 0
# 88.39905249018217
# Set parameter MIPGap to value 0
# 64.71983586404255
# Set parameter MIPGap to value 0
# 110.77984986033496
# Set parameter MIPGap to value 0
# 204.5097981369369
# Set parameter MIPGap to value 0
# 91.30197335916064
# =====================  Levy_f D7
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DC0D310>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 7, objective 3.376, evaluation 43
# TR update: iteration 11, objective 3.024, evaluation 65
# TR update: iteration 13, objective 2.845, evaluation 75
# TR update: iteration 14, objective 2.764, evaluation 81
# TR update: iteration 15, objective 2.621, evaluation 86
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 131.46586726218553
# Set parameter MIPGap to value 0
# 64.19737310112401
# Set parameter MIPGap to value 0
# 65.74189760636484
# Set parameter MIPGap to value 0
# 58.40845174920376
# Set parameter MIPGap to value 0
# 54.219888556845454
# Set parameter MIPGap to value 0
# 16.49220524739493
# Set parameter MIPGap to value 0
# 24.182081324280844
# Set parameter MIPGap to value 0
# 33.02076998463603
# Set parameter MIPGap to value 0
# 23.16704547716113
# Set parameter MIPGap to value 0
# 26.04605731191338
# Set parameter MIPGap to value 0
# 17.017613076216357
# Set parameter MIPGap to value 0
# 6.604300494413996
# Set parameter MIPGap to value 0
# 15.341142260497506
# Set parameter MIPGap to value 0
# 7.3541780669404755
# Set parameter MIPGap to value 0
# 11.996227180815463
# Set parameter MIPGap to value 0
# 12.710751946375854
# Set parameter MIPGap to value 0
# 9.017529401188511
# Set parameter MIPGap to value 0
# 9.031596022229545
# Set parameter MIPGap to value 0
# 8.655887099404964
# Set parameter MIPGap to value 0
# 7.277096673166063
# Set parameter MIPGap to value 0
# 15.81067487802552
# Set parameter MIPGap to value 0
# 10.203099065059765
# Set parameter MIPGap to value 0
# 4.0021736529298995
# Set parameter MIPGap to value 0
# 15.71327372848874
# Set parameter MIPGap to value 0
# 6.089785570531574
# Set parameter MIPGap to value 0
# 5.593903914208468
# Set parameter MIPGap to value 0
# 15.109812282130616
# Set parameter MIPGap to value 0
# 19.949372904142344
# Set parameter MIPGap to value 0
# 7.023156285808862
# Set parameter MIPGap to value 0
# 7.476301172974976
# Set parameter MIPGap to value 0
# 5.935216376944435
# Set parameter MIPGap to value 0
# 7.176845975109219
# Set parameter MIPGap to value 0
# 5.966120591339475
# Set parameter MIPGap to value 0
# 4.785293182915045
# Set parameter MIPGap to value 0
# 3.3521257981819197
# Set parameter MIPGap to value 0
# 3.461262495229756
# Set parameter MIPGap to value 0
# 4.9491592366064046
# Set parameter MIPGap to value 0
# 3.6907740477886786
# Set parameter MIPGap to value 0
# 4.6133669807820645
# Set parameter MIPGap to value 0
# 6.930336428350275
# Set parameter MIPGap to value 0
# 3.4637452396640382
# Set parameter MIPGap to value 0
# 40.53919269804775
# Set parameter MIPGap to value 0
# 3.4444026514617314
# Set parameter MIPGap to value 0
# 4.5210366523962975
# Set parameter MIPGap to value 0
# 3.1984446541996103
# Set parameter MIPGap to value 0
# 3.9723673038378498
# Set parameter MIPGap to value 0
# 3.2916662021076943
# Set parameter MIPGap to value 0
# 4.157827467235848
# Set parameter MIPGap to value 0
# 4.700923251165431
# Set parameter MIPGap to value 0
# 3.4527445450020458
# Set parameter MIPGap to value 0
# 4.842644154607105
# Set parameter MIPGap to value 0
# 5.396507223759645
# Set parameter MIPGap to value 0
# 3.4386208685955033
# Set parameter MIPGap to value 0
# 3.6481046228180074
# Set parameter MIPGap to value 0
# 3.8547364934210515
# Set parameter MIPGap to value 0
# 3.3093344779898377
# Set parameter MIPGap to value 0
# 3.9961638315715726
# Set parameter MIPGap to value 0
# 11.614105369937118
# Set parameter MIPGap to value 0
# 5.008879578308895
# Set parameter MIPGap to value 0
# 18.924830692630586
# Set parameter MIPGap to value 0
# 6.808160251352461
# Set parameter MIPGap to value 0
# 4.912026399929784
# Set parameter MIPGap to value 0
# 3.2487503045603696
# Set parameter MIPGap to value 0
# 84.01579819884195
# Set parameter MIPGap to value 0
# 3.805380106024436
# Set parameter MIPGap to value 0
# 3.503849325139747
# Set parameter MIPGap to value 0
# 4.37864674156218
# Set parameter MIPGap to value 0
# 4.555035930405325
# Set parameter MIPGap to value 0
# 4.003949310816692
# Set parameter MIPGap to value 0
# 3.9110724587711614
# Set parameter MIPGap to value 0
# 4.578138930904322
# Set parameter MIPGap to value 0
# 3.8285953126089654
# Set parameter MIPGap to value 0
# 4.05474138894771
# Set parameter MIPGap to value 0
# 4.324556431295297
# Set parameter MIPGap to value 0
# 3.928378265536117
# Set parameter MIPGap to value 0
# 3.1576551681186777
# Set parameter MIPGap to value 0
# 3.739290634765427
# Set parameter MIPGap to value 0
# 4.016289345273968
# Set parameter MIPGap to value 0
# 3.3672429208868024
# Set parameter MIPGap to value 0
# 3.5797361704781796
# Set parameter MIPGap to value 0
# 3.419070331599876
# Set parameter MIPGap to value 0
# 3.603351210200765
# Set parameter MIPGap to value 0
# 3.664806957753487
# Set parameter MIPGap to value 0
# 3.1381648053847426
# Set parameter MIPGap to value 0
# 3.8193912260469842
# Set parameter MIPGap to value 0
# 3.5557137753295995
# Set parameter MIPGap to value 0
# 4.232555391591512
# Set parameter MIPGap to value 0
# 3.2452626348555103
# Set parameter MIPGap to value 0
# 4.199287874097371
# Set parameter MIPGap to value 0
# 4.043252360581445
# Set parameter MIPGap to value 0
# 3.2656385644783197
# Set parameter MIPGap to value 0
# 4.070920373930452
# Set parameter MIPGap to value 0
# 4.0934402482948355
# Set parameter MIPGap to value 0
# 3.975525122255167
# Set parameter MIPGap to value 0
# 3.9415627344358515
# Set parameter MIPGap to value 0
# 5.153873984630124
# Set parameter MIPGap to value 0
# 3.849573829021953
# Set parameter MIPGap to value 0
# 3.4093047973859245
# Set parameter MIPGap to value 0
# 3.366618480172222
# Set parameter MIPGap to value 0
# 3.4205119993691313
# =====================  Ackley_f D7
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9FD4D150>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 6, objective 11.849, evaluation 37
# TR update: iteration 7, objective 11.094, evaluation 41
# TR update: iteration 11, objective 10.854, evaluation 64
# TR update: iteration 14, objective 10.707, evaluation 82
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 16.275852020202265
# Set parameter MIPGap to value 0
# 15.743061400573875
# Set parameter MIPGap to value 0
# 15.605254931106593
# Set parameter MIPGap to value 0
# 12.490115533538383
# Set parameter MIPGap to value 0
# 13.851266125144388
# Set parameter MIPGap to value 0
# 13.250651461277211
# Set parameter MIPGap to value 0
# 10.725960321193138
# Set parameter MIPGap to value 0
# 11.873265830992702
# Set parameter MIPGap to value 0
# 13.797159886320667
# Set parameter MIPGap to value 0
# 12.275281867077043
# Set parameter MIPGap to value 0
# 12.584076548007218
# Set parameter MIPGap to value 0
# 12.790384300748187
# Set parameter MIPGap to value 0
# 10.794932248692723
# Set parameter MIPGap to value 0
# 10.389030913252206
# Set parameter MIPGap to value 0
# 8.171826738108209
# Set parameter MIPGap to value 0
# 10.155449296535725
# Set parameter MIPGap to value 0
# 13.758463312663851
# Set parameter MIPGap to value 0
# 11.727182418088658
# Set parameter MIPGap to value 0
# 12.234615023615824
# Set parameter MIPGap to value 0
# 13.584996700399165
# Set parameter MIPGap to value 0
# 11.370871788524475
# Set parameter MIPGap to value 0
# 11.780961075884282
# Set parameter MIPGap to value 0
# 8.66089834789399
# Set parameter MIPGap to value 0
# 10.766698263839997
# Set parameter MIPGap to value 0
# 11.581622792602065
# Set parameter MIPGap to value 0
# 10.328640638486334
# Set parameter MIPGap to value 0
# 10.362464198834175
# Set parameter MIPGap to value 0
# 7.974661290218622
# Set parameter MIPGap to value 0
# 7.096852772020384
# Set parameter MIPGap to value 0
# 10.872202300874195
# Set parameter MIPGap to value 0
# 9.347963328938471
# Set parameter MIPGap to value 0
# 9.386724950643313
# Set parameter MIPGap to value 0
# 12.741926998768266
# Set parameter MIPGap to value 0
# 8.154083966445533
# Set parameter MIPGap to value 0
# 8.86935434361313
# Set parameter MIPGap to value 0
# 8.274326108484209
# Set parameter MIPGap to value 0
# 7.8369466741871765
# Set parameter MIPGap to value 0
# 7.1889921766048275
# Set parameter MIPGap to value 0
# 9.259650653546553
# Set parameter MIPGap to value 0
# 7.244519295689708
# Set parameter MIPGap to value 0
# 6.772850838488029
# Set parameter MIPGap to value 0
# 6.9826492782066545
# Set parameter MIPGap to value 0
# 7.977590342304307
# Set parameter MIPGap to value 0
# 10.362729803106662
# Set parameter MIPGap to value 0
# 8.690862355625907
# Set parameter MIPGap to value 0
# 7.706925187180341
# Set parameter MIPGap to value 0
# 6.194357204686465
# Set parameter MIPGap to value 0
# 8.665941637663972
# Set parameter MIPGap to value 0
# 6.936917201771244
# Set parameter MIPGap to value 0
# 6.880991702345032
# Set parameter MIPGap to value 0
# 7.54643708569321
# Set parameter MIPGap to value 0
# 6.627956752972295
# Set parameter MIPGap to value 0
# 6.153763809809902
# Set parameter MIPGap to value 0
# 6.306952051211734
# Set parameter MIPGap to value 0
# 6.693077841115784
# Set parameter MIPGap to value 0
# 6.693420312051483
# Set parameter MIPGap to value 0
# 6.460811315939047
# Set parameter MIPGap to value 0
# 6.470947104746305
# Set parameter MIPGap to value 0
# 6.012163946561461
# Set parameter MIPGap to value 0
# 6.247204384954049
# Set parameter MIPGap to value 0
# 6.474254300967868
# Set parameter MIPGap to value 0
# 6.7711357325244315
# Set parameter MIPGap to value 0
# 6.552193850187042
# Set parameter MIPGap to value 0
# 6.387626731616351
# Set parameter MIPGap to value 0
# 6.339567903143994
# Set parameter MIPGap to value 0
# 6.474069229083213
# Set parameter MIPGap to value 0
# 6.343439276037071
# Set parameter MIPGap to value 0
# 7.060711500125981
# Set parameter MIPGap to value 0
# 6.697635415296698
# Set parameter MIPGap to value 0
# 6.44227893117084
# Set parameter MIPGap to value 0
# 6.698296919608438
# Set parameter MIPGap to value 0
# 6.512066753249137
# Set parameter MIPGap to value 0
# 6.442825798440833
# Set parameter MIPGap to value 0
# 5.994518606165286
# Set parameter MIPGap to value 0
# 10.629824981372478
# Set parameter MIPGap to value 0
# 6.423023597550365
# Set parameter MIPGap to value 0
# 7.892435999191578
# Set parameter MIPGap to value 0
# 6.1671159258677335
# Set parameter MIPGap to value 0
# 5.7701153311433835
# Set parameter MIPGap to value 0
# 6.229164254831243
# Set parameter MIPGap to value 0
# 5.76905664669648
# Set parameter MIPGap to value 0
# 5.810658990344468
# Set parameter MIPGap to value 0
# 6.02573513519841
# Set parameter MIPGap to value 0
# 5.5608509053470065
# Set parameter MIPGap to value 0
# 5.873178729933311
# Set parameter MIPGap to value 0
# 5.4701757760539245
# Set parameter MIPGap to value 0
# 5.947319643859078
# Set parameter MIPGap to value 0
# 5.4964027661731905
# Set parameter MIPGap to value 0
# 5.76571012631711
# Set parameter MIPGap to value 0
# 6.145786545609546
# Set parameter MIPGap to value 0
# 5.807214468915067
# Set parameter MIPGap to value 0
# 5.68968011104872
# Set parameter MIPGap to value 0
# 5.502926238818922
# Set parameter MIPGap to value 0
# 5.655528318387443
# Set parameter MIPGap to value 0
# 5.518119590023808
# Set parameter MIPGap to value 0
# 5.55643643894992
# Set parameter MIPGap to value 0
# 5.83477226818821
# Set parameter MIPGap to value 0
# 5.48176947607903
# Set parameter MIPGap to value 0
# 5.654378416023288
# Set parameter MIPGap to value 0
# 5.2092220182854625
# =====================  Rosenbrock_f D7
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DB0D350>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 2, objective 52131.161, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 4, objective 40481.675, evaluation 24
# TR update: iteration 5, objective 30650.355, evaluation 29
# TR update: iteration 6, objective 23135.106, evaluation 33
# TR update: iteration 7, objective 20091.328, evaluation 39
# TR update: iteration 8, objective 15618.605, evaluation 42
# TR update: iteration 9, objective 14040.616, evaluation 47
# TR update: iteration 11, objective 11128.693, evaluation 58
# TR update: iteration 12, objective 10002.691, evaluation 62
# TR update: iteration 13, objective 7997.653, evaluation 68
# TR update: iteration 14, objective 7778.373, evaluation 73
# TR update: iteration 15, objective 7411.619, evaluation 79
# TR update: iteration 16, objective 6725.031, evaluation 85
# TR update: iteration 17, objective 5894.856, evaluation 89
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 1286639.1870619955
# Set parameter MIPGap to value 0
# 370298.4498534056
# Set parameter MIPGap to value 0
# 119361.6445925102
# Set parameter MIPGap to value 0
# 495231.155038895
# Set parameter MIPGap to value 0
# 233728.23843339944
# Set parameter MIPGap to value 0
# 582013.6193581765
# Set parameter MIPGap to value 0
# 75839.29273639272
# Set parameter MIPGap to value 0
# 123874.89203803489
# Set parameter MIPGap to value 0
# 41062.050218430995
# Set parameter MIPGap to value 0
# 424502.34569943586
# Set parameter MIPGap to value 0
# 866025.8544719511
# Set parameter MIPGap to value 0
# 113693.08888692588
# Set parameter MIPGap to value 0
# 76958.16400762986
# Set parameter MIPGap to value 0
# 51369.51585066027
# Set parameter MIPGap to value 0
# 459610.224399678
# Set parameter MIPGap to value 0
# 226119.58957959377
# Set parameter MIPGap to value 0
# 243660.62184489862
# Set parameter MIPGap to value 0
# 112309.28383148286
# Set parameter MIPGap to value 0
# 136262.00335449754
# Set parameter MIPGap to value 0
# 33569.05065612202
# Set parameter MIPGap to value 0
# 9073.649057175204
# Set parameter MIPGap to value 0
# 26291.3806449248
# Set parameter MIPGap to value 0
# 41870.402811837186
# Set parameter MIPGap to value 0
# 91317.67622446675
# Set parameter MIPGap to value 0
# 9437.198845225892
# Set parameter MIPGap to value 0
# 18449.301241007684
# Set parameter MIPGap to value 0
# 21129.245220924116
# Set parameter MIPGap to value 0
# 22238.1958077976
# Set parameter MIPGap to value 0
# 14134.975834986097
# Set parameter MIPGap to value 0
# 21128.9060625206
# Set parameter MIPGap to value 0
# 68308.78988149697
# Set parameter MIPGap to value 0
# 15025.369190951335
# Set parameter MIPGap to value 0
# 809807.4549552054
# Set parameter MIPGap to value 0
# 43533.447421469566
# Set parameter MIPGap to value 0
# 48063.908431310585
# Set parameter MIPGap to value 0
# 12416.735919914227
# Set parameter MIPGap to value 0
# 33369.66785879693
# Set parameter MIPGap to value 0
# 240529.81571167693
# Set parameter MIPGap to value 0
# 49738.80701348458
# Set parameter MIPGap to value 0
# 248786.68389035243
# Set parameter MIPGap to value 0
# 26424.25721307131
# Set parameter MIPGap to value 0
# 23803.308892204514
# Set parameter MIPGap to value 0
# 31637.146937500158
# Set parameter MIPGap to value 0
# 34116.23418192704
# Set parameter MIPGap to value 0
# 22146.175144693258
# Set parameter MIPGap to value 0
# 50596.2632790496
# Set parameter MIPGap to value 0
# 197775.9080519716
# Set parameter MIPGap to value 0
# 83508.22564415315
# Set parameter MIPGap to value 0
# 30415.379046045397
# Set parameter MIPGap to value 0
# 23942.06217731234
# Set parameter MIPGap to value 0
# 9401.000430017719
# Set parameter MIPGap to value 0
# 28177.584354609822
# Set parameter MIPGap to value 0
# 39021.047165419775
# Set parameter MIPGap to value 0
# 46353.87535449792
# Set parameter MIPGap to value 0
# 28974.966739480078
# Set parameter MIPGap to value 0
# 23443.4483637507
# Set parameter MIPGap to value 0
# 13426.788531862672
# Set parameter MIPGap to value 0
# 17133.90493773956
# Set parameter MIPGap to value 0
# 13258.648941245267
# Set parameter MIPGap to value 0
# 12322.919793646894
# Set parameter MIPGap to value 0
# 28586.233719492193
# Set parameter MIPGap to value 0
# 21513.898388622387
# Set parameter MIPGap to value 0
# 101584.49311879737
# Set parameter MIPGap to value 0
# 25728.807146542633
# Set parameter MIPGap to value 0
# 25551.193322598298
# Set parameter MIPGap to value 0
# 45417.38170829044
# Set parameter MIPGap to value 0
# 22274.221720056612
# Set parameter MIPGap to value 0
# 34132.85809955032
# Set parameter MIPGap to value 0
# 27754.893988707136
# Set parameter MIPGap to value 0
# 8493.558054382751
# Set parameter MIPGap to value 0
# 47646.35597804184
# Set parameter MIPGap to value 0
# 30225.261240578748
# Set parameter MIPGap to value 0
# 9564.64859936307
# Set parameter MIPGap to value 0
# 40464.200123581664
# Set parameter MIPGap to value 0
# 40462.55702673938
# Set parameter MIPGap to value 0
# 22075.587939967594
# Set parameter MIPGap to value 0
# 10990.7388600393
# Set parameter MIPGap to value 0
# 12210.32045194857
# Set parameter MIPGap to value 0
# 26428.57493661732
# Set parameter MIPGap to value 0
# 16080.741657071347
# Set parameter MIPGap to value 0
# 78378.48589281736
# Set parameter MIPGap to value 0
# 12366.151476190877
# Set parameter MIPGap to value 0
# 39997.89704973404
# Set parameter MIPGap to value 0
# 26535.04956534365
# Set parameter MIPGap to value 0
# 20294.14160838715
# Set parameter MIPGap to value 0
# 14015.152349377131
# Set parameter MIPGap to value 0
# 19725.377044780922
# Set parameter MIPGap to value 0
# 17813.84440831772
# Set parameter MIPGap to value 0
# 14122.34852782498
# Set parameter MIPGap to value 0
# 18362.41105154399
# Set parameter MIPGap to value 0
# 37102.96081847917
# Set parameter MIPGap to value 0
# 10396.280918786304
# Set parameter MIPGap to value 0
# 22840.44618619419
# Set parameter MIPGap to value 0
# 9456.305613542261
# Set parameter MIPGap to value 0
# 19645.186750757406
# Set parameter MIPGap to value 0
# 11466.124769403292
# Set parameter MIPGap to value 0
# 9535.234146906483
# Set parameter MIPGap to value 0
# 35324.256926762864
# Set parameter MIPGap to value 0
# 17199.225576126708
# Set parameter MIPGap to value 0
# 19439.417103011747
# =====================  Antonio_f D7
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000001FB9DC56C10>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 2, objective 11053.718, evaluation 13
# TR update: iteration 3, objective 10261.154, evaluation 17
# TR update: iteration 4, objective 9267.540, evaluation 22
# TR update: iteration 5, objective 8013.757, evaluation 27
# TR update: iteration 6, objective 6973.691, evaluation 32
# TR update: iteration 7, objective 6402.017, evaluation 35
# TR update: iteration 8, objective 6157.377, evaluation 40
# TR update: iteration 9, objective 5281.308, evaluation 45
# TR update: iteration 10, objective 4432.590, evaluation 50
# TR update: iteration 11, objective 3560.320, evaluation 55
# TR update: iteration 12, objective 2896.299, evaluation 59
# TR update: iteration 13, objective 2428.340, evaluation 64
# TR update: iteration 14, objective 2121.110, evaluation 70
# TR update: iteration 15, objective 1744.232, evaluation 75
# TR update: iteration 16, objective 1340.664, evaluation 80
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
# Set parameter MIPGap to value 0
# 37799.36122300929
# Set parameter MIPGap to value 0
# 28235.747458138034
# Set parameter MIPGap to value 0
# 16114.700708849003
# Set parameter MIPGap to value 0
# 19551.545746079497
# Set parameter MIPGap to value 0
# 10101.095411068447
# Set parameter MIPGap to value 0
# 9142.177719521767
# Set parameter MIPGap to value 0
# 28241.356549800756
# Set parameter MIPGap to value 0
# 19215.226285478202
# Set parameter MIPGap to value 0
# 10217.66057564605
# Set parameter MIPGap to value 0
# 13167.97172493417
# Set parameter MIPGap to value 0
# 10753.143845082124
# Set parameter MIPGap to value 0
# 14241.966976360101
# Set parameter MIPGap to value 0
# 10919.314839093753
# Set parameter MIPGap to value 0
# 8982.179343925925
# Set parameter MIPGap to value 0
# 15801.287516343351
# Set parameter MIPGap to value 0
# 5039.215406451286
# Set parameter MIPGap to value 0
# 13248.998757030477
# Set parameter MIPGap to value 0
# 4195.887834130274
# Set parameter MIPGap to value 0
# 5829.784285211946
# Set parameter MIPGap to value 0
# 10133.562030364654
# Set parameter MIPGap to value 0
# 9644.02795930805
# Set parameter MIPGap to value 0
# 4925.027159589049
# Set parameter MIPGap to value 0
# 5299.548909089642
# Set parameter MIPGap to value 0
# 9947.34286767347
# Set parameter MIPGap to value 0
# 5455.377813362639
# Set parameter MIPGap to value 0
# 4977.355290884397
# Set parameter MIPGap to value 0
# 5168.299437097772
# Set parameter MIPGap to value 0
# 4013.0056812271255
# Set parameter MIPGap to value 0
# 4829.50023673919
# Set parameter MIPGap to value 0
# 5265.252183095774
# Set parameter MIPGap to value 0
# 23011.180203203483
# Set parameter MIPGap to value 0
# 4235.432331347697
# Set parameter MIPGap to value 0
# 6120.549264542741
# Set parameter MIPGap to value 0
# 5704.953927086161
# Set parameter MIPGap to value 0
# 7234.225325322437
# Set parameter MIPGap to value 0
# 3662.872853413123
# Set parameter MIPGap to value 0
# 3825.0730685171247
# Set parameter MIPGap to value 0
# 3594.7601321843495
# Set parameter MIPGap to value 0
# 4482.28900227504
# Set parameter MIPGap to value 0
# 5126.0184158852235
# Set parameter MIPGap to value 0
# 3679.7444268327504
# Set parameter MIPGap to value 0
# 4427.59243199125
# Set parameter MIPGap to value 0
# 4726.308028772902
# Set parameter MIPGap to value 0
# 4066.0597003557764
# Set parameter MIPGap to value 0
# 6540.4798839766345
# Set parameter MIPGap to value 0
# 3278.0236012078094
# Set parameter MIPGap to value 0
# 3626.448071704889
# Set parameter MIPGap to value 0
# 3008.8527126493163
# Set parameter MIPGap to value 0
# 4289.847842647363
# Set parameter MIPGap to value 0
# 3974.113634852477
# Set parameter MIPGap to value 0
# 2949.732700180089
# Set parameter MIPGap to value 0
# 3974.1481967229633
# Set parameter MIPGap to value 0
# 3141.8745395341907
# Set parameter MIPGap to value 0
# 3091.068596988607
# Set parameter MIPGap to value 0
# 3134.4655809552787
# Set parameter MIPGap to value 0
# 3196.9411934355585
# Set parameter MIPGap to value 0
# 3532.4343096810458
# Set parameter MIPGap to value 0
# 4113.534436941734
# Set parameter MIPGap to value 0
# 3908.8984938491635
# Set parameter MIPGap to value 0
# 3004.486550729092
# Set parameter MIPGap to value 0
# 3408.2642643749223
# Set parameter MIPGap to value 0
# 2728.9259814903107
# Set parameter MIPGap to value 0
# 3165.26862320293
# Set parameter MIPGap to value 0
# 2845.224269266141
# Set parameter MIPGap to value 0
# 3515.669047457724
# Set parameter MIPGap to value 0
# 3062.6644254485113
# Set parameter MIPGap to value 0
# 3517.8603744707743
# Set parameter MIPGap to value 0
# 2860.988600750614
# Set parameter MIPGap to value 0
# 3596.6248820342626
# Set parameter MIPGap to value 0
# 4889.3951266926215
# Set parameter MIPGap to value 0
# 3024.1932172634433
# Set parameter MIPGap to value 0
# 3170.58867144729
# Set parameter MIPGap to value 0
# 3158.6986028569436
# Set parameter MIPGap to value 0
# 9339.92147045019
# Set parameter MIPGap to value 0
# 3065.667021512796
# Set parameter MIPGap to value 0
# 3094.388269125091
# Set parameter MIPGap to value 0
# 3742.251218291572
# Set parameter MIPGap to value 0
# 3566.6078321934665
# Set parameter MIPGap to value 0
# 7150.387054079957
# Set parameter MIPGap to value 0
# 3307.651376616358
# Set parameter MIPGap to value 0
# 3165.8000620612925
# Set parameter MIPGap to value 0
# 2972.6136878529605
# Set parameter MIPGap to value 0
# 3270.1612624222353
# Set parameter MIPGap to value 0
# 2997.3497088193985
# Set parameter MIPGap to value 0
# 3118.794417303278
# Set parameter MIPGap to value 0
# 2565.7954719467484
# Set parameter MIPGap to value 0
# 2821.342169349294
# Set parameter MIPGap to value 0
# 2837.7891084070375
# Set parameter MIPGap to value 0
# 2759.0935858486837
# Set parameter MIPGap to value 0
# 2642.763433860063
# Set parameter MIPGap to value 0
# 2979.932999195312
# Set parameter MIPGap to value 0
# 2963.4179176878047
# Set parameter MIPGap to value 0
# 3024.9483741598474
# Set parameter MIPGap to value 0
# 3228.940709721705
# Set parameter MIPGap to value 0
# 2846.759289108035
# Set parameter MIPGap to value 0
# 2742.148844682663
# Set parameter MIPGap to value 0
# 3046.3654448592442
# Set parameter MIPGap to value 0
# 2641.1702530526286
# Set parameter MIPGap to value 0
# 3391.5839059782193
# Set parameter MIPGap to value 0
# 3008.84121465805

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\Coursework1_DDO\benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-04-15_07-43-43\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# %% [markdown]
# ### Plot performance tables

# %%
array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)
# Out:
# ==   LS_QM_v2  ==
# ==   opt_SnobFit  ==
# ==   opt_SRBF  ==
# ==   opt_DYCORS  ==
# ==   opt_SOP  ==
# ==   opt_COBYLA  ==
# ==   COBYQA  ==
# ==   opt_CUATRO  ==
# ==   BO_np_scipy  ==
# ==   opt_ENTMOOT  ==
# ==   LS_QM_v2  ==
# ==   opt_SnobFit  ==
# ==   opt_SRBF  ==
# ==   opt_DYCORS  ==
# ==   opt_SOP  ==
# ==   opt_COBYLA  ==
# ==   COBYQA  ==
# ==   opt_CUATRO  ==
# ==   BO_np_scipy  ==
# ==   opt_ENTMOOT  ==
# ==   LS_QM_v2  ==
# ==   opt_SnobFit  ==
# ==   opt_SRBF  ==
# ==   opt_DYCORS  ==
# ==   opt_SOP  ==
# ==   opt_COBYLA  ==
# ==   COBYQA  ==
# ==   opt_CUATRO  ==
# ==   BO_np_scipy  ==
# ==   opt_ENTMOOT  ==

# %%
# timestamp = '2024-04-15_07-43-43'

# %%
ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = False)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=False)
