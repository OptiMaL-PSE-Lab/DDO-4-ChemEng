# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *
from ENTMOOT import *


##########################
# Algorithms & Functions #
##########################



algorithms_test = [
    # LS_QM_v2,
    # opt_SnobFit,
    # opt_SRBF,
    # opt_DYCORS,
    # opt_SOP,
    # opt_COBYLA,
    # COBYQA,
    # opt_CUATRO,
    # opt_CUATRO_pls,
    BO_np_scipy,
    # opt_ENTMOOT,
    ]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    5,
    7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 2                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    50,
    100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

home_dir  = 'images/trajectory_plots_1D_&_tables'

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  Levy_f D2
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 17/17 [00:06<00:00,  2.58it/s]
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
#  82%|████████▏ | 14/17 [00:04<00:01,  2.93it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\utils.py:156, in ML4CE_uncon_eval(N_x_l, f_eval_l, functions_test, algorithms_test, reps, home_dir, SafeData)
#     154 t_       = Test_function(i_function, N_x_, True, x_shift_, bounds_)
#     155 # algorithm
# --> 156 a, b, team_names, cids = i_algorithm(t_, N_x_, bounds_, f_eval_)
#     157 # post-processing
#     158 t_.best_f_list()                    # List of best points so far
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\BO_NpScpy.py:590, in BO_np_scipy(f, x_dim, bounds, iter_tot, has_x0)
#     579     d_     = ['int', bounds, n_rs]
#     581 GP_opt = GP_optimizer(
#     582     f.fun_test,
#     583     d_,
#    (...)
#     587     EI_bool=False
#     588     )
# --> 590 X_opt, y_opt = GP_opt.optimization_routine()
#     591 i_best       = np.argmin(y_opt)
#     592 x_best       = X_opt[i_best]
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\BO_NpScpy.py:545, in GP_optimizer.optimization_routine(self)
#     542 y_opt  = np.vstack((y_opt,ynew))
#     543 # re-training GP
#     544 # print('GP_optimizer: optimisation routine: after iteration ' + str(i_opt+1) + ' the GP is now re-trained based on the updated X_opt and y_opt')
# --> 545 GP_m   = GP_model(X_opt, y_opt, 'RBF', multi_hyper=10, var_out=True)
#     547 # print('GP_optimizer: optimisation routine: checking for expected improvement in the end of iteration ' + str(i_opt+1))
#     548 if self.EI_bool==True:
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\BO_NpScpy.py:41, in GP_model.__init__(self, X, Y, kernel, multi_hyper, var_out)
#      37 self.X_norm, self.Y_norm    = (X-self.X_mean)/self.X_std, (Y-self.Y_mean)/self.Y_std
#      39 # print('GP_model: __init__: Determining Hyperparameters in a loop that repeatedly calls negative_loglikelihood which calls Cov_mat')
#      40 # determine hyperparameters
# ---> 41 self.hypopt, self.invKopt   = self.determine_hyperparameters()
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\BO_NpScpy.py:151, in GP_model.determine_hyperparameters(self)
#     149 hyp_init    = lb + (ub-lb)*multi_startvec[j,:]
#     150 # --- hyper-parameter optimization --- #
# --> 151 res = minimize(self.negative_loglikelihood,hyp_init,args=(X_norm,Y_norm[:,i])\
#     152                ,method='SLSQP',options=options,bounds=bounds,tol=1e-12)
#     153 localsol[j] = res.x
#     154 localval[j] = res.fun
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:719, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     716     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     717                            bounds=bounds, **options)
#     718 elif meth == 'slsqp':
# --> 719     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     720                           constraints, callback=callback, **options)
#     721 elif meth == 'trust-constr':
#     722     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     723                                        bounds, constraints,
#     724                                        callback=callback, **options)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_slsqp_py.py:428, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     422 slsqp(m, meq, x, xl, xu, fx, c, g, a, acc, majiter, mode, w, jw,
#     423       alpha, f0, gs, h1, h2, h3, h4, t, t0, tol,
#     424       iexact, incons, ireset, itermx, line,
#     425       n1, n2, n3)
#     427 if mode == 1:  # objective and constraint evaluation required
# --> 428     fx = wrapped_fun(x)
#     429     c = _eval_constraint(x, cons)
#     431 if mode == -1:  # gradient evaluation required
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:397, in _clip_x_for_func.<locals>.eval(x)
#     395 def eval(x):
#     396     x = _check_clip_x(x, bounds)
# --> 397     return func(x)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:266, in ScalarFunction.fun(self, x)
#     264 def fun(self, x):
#     265     if not np.array_equal(x, self.x):
# --> 266         self._update_x_impl(x)
#     267     self._update_fun()
#     268     return self.f
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:243, in ScalarFunction.__init__.<locals>.update_x(x)
#     240 def update_x(x):
#     241     # ensure that self.x is a copy of x. Don't store a reference
#     242     # otherwise the memoization doesn't work properly.
# --> 243     self.x = np.atleast_1d(x).astype(float)
#     244     self.f_updated = False
#     245     self.g_updated = False
#
# KeyboardInterrupt:

# %% [markdown]
# ### Benchmark

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-06-11_18-46-16\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-06-11_18-46-16'

# %% [markdown]
# ### Plot performance tables

# %%
array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)
# Out:
# ==   opt_DYCORS  ==
# ==   opt_CUATRO  ==
# ==   opt_CUATRO_pls  ==
# ==   opt_DYCORS  ==
# ==   opt_CUATRO  ==
# ==   opt_CUATRO_pls  ==

# %%
ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = False)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=False)

# %%
# ML4CE_uncon_graph_rel(trajectories, algorithms_test, functions_test, N_x_l)
