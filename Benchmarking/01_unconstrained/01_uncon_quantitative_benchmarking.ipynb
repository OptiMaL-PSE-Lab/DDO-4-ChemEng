# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *


##########################
# Algorithms & Functions #
##########################

home_dir  = 'images/trajectory_plots_1D_&_tables'

algorithms_test = [
    LS_QM_v2, # TODO this needs to be updated to take an initial point, also for the qualitative benchmarking
    opt_SnobFit,
    opt_SRBF,
    opt_DYCORS,
    opt_SOP,
    opt_COBYLA,
    COBYQA,
    opt_CUATRO,
# # Feel free to add these commented-out algorithms as a further test,
# # however, do note they are more time-consuming to run
BO_np_scipy
]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    # 5,
    # 7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 5                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    50,
    100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

# %% [markdown]
# ### Benchmark

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  Levy_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000002480F3ADB10>
# <poap.strategy.EvalRecord object at 0x000002480F3D6C50>
# <poap.strategy.EvalRecord object at 0x000002480F3E7E90>
# <poap.strategy.EvalRecord object at 0x000002480F3A8E90>
# <poap.strategy.EvalRecord object at 0x000002480E02FD10>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 1, objective 0.002, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 2, objective 0.072, evaluation 13
# TR update: iteration 2, objective 0.009, evaluation 13
# TR update: iteration 1, objective 0.070, evaluation 7
# TR update: iteration 2, objective 0.009, evaluation 13
# TR update: iteration 2, objective 0.521, evaluation 13
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# =====================  Ackley_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x00000248574D4B50>
# <poap.strategy.EvalRecord object at 0x000002480F3D6050>
# <poap.strategy.EvalRecord object at 0x00000248574FA8D0>
# <poap.strategy.EvalRecord object at 0x00000248574FA150>
# <poap.strategy.EvalRecord object at 0x00000248574F9110>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 1, objective 8.458, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 1, objective 8.779, evaluation 7
# TR update: iteration 2, objective 6.219, evaluation 13
# TR update: iteration 1, objective 3.472, evaluation 7
# TR update: iteration 2, objective 0.574, evaluation 12
# TR update: iteration 1, objective 9.565, evaluation 7
# TR update: iteration 2, objective 7.968, evaluation 12
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# =====================  Rosenbrock_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x000002480DD50F90>
# <poap.strategy.EvalRecord object at 0x000002480F37AC50>
# <poap.strategy.EvalRecord object at 0x000002480F3C2B50>
# <poap.strategy.EvalRecord object at 0x000002480DAA4B90>
# <poap.strategy.EvalRecord object at 0x000002480F3FF350>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 2, objective 2265.076, evaluation 13
# TR update: iteration 3, objective 891.195, evaluation 15
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 1, objective 4261.930, evaluation 7
# TR update: iteration 2, objective 1903.406, evaluation 12
# TR update: iteration 3, objective 952.618, evaluation 15
# TR update: iteration 2, objective 9.218, evaluation 13
# TR update: iteration 2, objective 450.470, evaluation 13
# TR update: iteration 2, objective 10.211, evaluation 13
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# =====================  Antonio_f D2
# ==  LS_QM_v2
# ==  opt_SnobFit
# ==  opt_SRBF
# ==  opt_DYCORS
# <poap.strategy.EvalRecord object at 0x00000248574F9F50>
# <poap.strategy.EvalRecord object at 0x00000248574D5650>
# <poap.strategy.EvalRecord object at 0x0000024857472DD0>
# <poap.strategy.EvalRecord object at 0x0000024857470590>
# <poap.strategy.EvalRecord object at 0x000002480F39F190>
# ==  opt_SOP
# ==  opt_COBYLA
# ==  COBYQA
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:716: OptimizeWarning: Unknown solver options: maxfev
#   res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
# ==  opt_CUATRO
# TR update: iteration 1, objective 6.628, evaluation 7
# TR update: iteration 2, objective 0.220, evaluation 12
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# TR update: iteration 1, objective 0.000, evaluation 7
# TR update: iteration 1, objective 0.019, evaluation 7
# TR update: iteration 2, objective 0.000, evaluation 12
# TR update: iteration 1, objective 54.813, evaluation 7
# TR update: iteration 2, objective 27.681, evaluation 12
# TR update: iteration 3, objective 7.358, evaluation 15
# TR update: iteration 1, objective 14.457, evaluation 7
# TR update: iteration 2, objective 2.103, evaluation 13
# ==  BO_np_scipy
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------
# - No preliminar data supplied, computing data by sobol sequence
# ------------------------------------FINISH-----------------------------------------

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\Coursework1_DDO\benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-04-15_07-43-43\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# %% [markdown]
# ### Plot performance tables

# %%
array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)
# Out:
# ==   LS_QM_v2  ==
# ==   opt_SnobFit  ==
# ==   opt_SRBF  ==
# ==   opt_DYCORS  ==
# ==   opt_SOP  ==
# ==   opt_COBYLA  ==
# ==   COBYQA  ==
# ==   opt_CUATRO  ==
# ==   BO_np_scipy  ==

# %%
# timestamp = '2024-04-15_07-43-43'

# %%
ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = False)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=False)
