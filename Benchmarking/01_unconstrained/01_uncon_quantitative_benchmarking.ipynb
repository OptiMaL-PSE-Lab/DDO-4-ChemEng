# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *

##########################
# Algorithms & Functions #
##########################

home_dir  = 'images/trajectory_plots_1D_&_tables'

algorithms_test = [
    LS_QM_v2, # TODO this needs to be updated to take an initial point, also for the qualitative benchmarking
    # opt_COBYLA,
    # COBYQA,
# # Feel free to add these commented-out algorithms as a further test,
# # however, do note they are more time-consuming to run
# BO_np_scipy
]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    5,
    7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 5                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    50,
    100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

# %% [markdown]
# ### Benchmark

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  Levy_f D2
# ==  LS_QM_v2
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.0625
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.0625
# iter  6 / 17  radius =  0.125
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  1.0
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  1.0
# iter  12 / 17  radius =  0.5
# iter  13 / 17  radius =  1.0
# iter  14 / 17  radius =  2.0
# iter  15 / 17  radius =  4.0
# iter  16 / 17  radius =  8.0
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  1.0
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  1.0
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  2.0
# iter  9 / 17  radius =  4.0
# iter  10 / 17  radius =  8.0
# iter  11 / 17  radius =  4.0
# iter  12 / 17  radius =  2.0
# iter  13 / 17  radius =  1.0
# iter  14 / 17  radius =  0.5
# iter  15 / 17  radius =  0.25
# iter  16 / 17  radius =  0.125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.125
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  1.0
# iter  12 / 17  radius =  2.0
# iter  13 / 17  radius =  4.0
# iter  14 / 17  radius =  8.0
# iter  15 / 17  radius =  16.0
# iter  16 / 17  radius =  32.0
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  1.0
# iter  4 / 17  radius =  2.0
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.125
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  0.25
# iter  12 / 17  radius =  0.125
# iter  13 / 17  radius =  0.25
# iter  14 / 17  radius =  0.125
# iter  15 / 17  radius =  0.0625
# iter  16 / 17  radius =  0.03125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.0625
# iter  4 / 17  radius =  0.03125
# iter  5 / 17  radius =  0.0625
# iter  6 / 17  radius =  0.125
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  1.0
# iter  12 / 17  radius =  2.0
# iter  13 / 17  radius =  4.0
# iter  14 / 17  radius =  2.0
# iter  15 / 17  radius =  4.0
# iter  16 / 17  radius =  2.0
# =====================  Ackley_f D2
# ==  LS_QM_v2
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.125
# iter  11 / 17  radius =  0.0625
# iter  12 / 17  radius =  0.03125
# iter  13 / 17  radius =  0.015625
# iter  14 / 17  radius =  0.0078125
# iter  15 / 17  radius =  0.00390625
# iter  16 / 17  radius =  0.001953125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.25
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  1.0
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  0.25
# iter  12 / 17  radius =  0.125
# iter  13 / 17  radius =  0.0625
# iter  14 / 17  radius =  0.125
# iter  15 / 17  radius =  0.0625
# iter  16 / 17  radius =  0.125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.125
# iter  9 / 17  radius =  0.0625
# iter  10 / 17  radius =  0.03125
# iter  11 / 17  radius =  0.0625
# iter  12 / 17  radius =  0.03125
# iter  13 / 17  radius =  0.015625
# iter  14 / 17  radius =  0.0078125
# iter  15 / 17  radius =  0.00390625
# iter  16 / 17  radius =  0.001953125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.125
# iter  11 / 17  radius =  0.0625
# iter  12 / 17  radius =  0.03125
# iter  13 / 17  radius =  0.015625
# iter  14 / 17  radius =  0.0078125
# iter  15 / 17  radius =  0.00390625
# iter  16 / 17  radius =  0.001953125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  0.25
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  0.25
# iter  8 / 17  radius =  0.125
# iter  9 / 17  radius =  0.0625
# iter  10 / 17  radius =  0.03125
# iter  11 / 17  radius =  0.015625
# iter  12 / 17  radius =  0.0078125
# iter  13 / 17  radius =  0.00390625
# iter  14 / 17  radius =  0.001953125
# iter  15 / 17  radius =  0.0009765625
# iter  16 / 17  radius =  0.00048828125
# =====================  Rosenbrock_f D2
# ==  LS_QM_v2
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.0625
# iter  4 / 17  radius =  0.03125
# iter  5 / 17  radius =  0.015625
# iter  6 / 17  radius =  0.0078125
# iter  7 / 17  radius =  0.00390625
# iter  8 / 17  radius =  0.001953125
# iter  9 / 17  radius =  0.0009765625
# iter  10 / 17  radius =  0.00048828125
# iter  11 / 17  radius =  0.000244140625
# iter  12 / 17  radius =  0.0001220703125
# iter  13 / 17  radius =  0.0001
# iter  14 / 17  radius =  0.0001
# iter  15 / 17  radius =  0.0001
# iter  16 / 17  radius =  0.0001
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.0625
# iter  4 / 17  radius =  0.03125
# iter  5 / 17  radius =  0.015625
# iter  6 / 17  radius =  0.0078125
# iter  7 / 17  radius =  0.00390625
# iter  8 / 17  radius =  0.001953125
# iter  9 / 17  radius =  0.0009765625
# iter  10 / 17  radius =  0.00048828125
# iter  11 / 17  radius =  0.000244140625
# iter  12 / 17  radius =  0.0001220703125
# iter  13 / 17  radius =  0.0001
# iter  14 / 17  radius =  0.0001
# iter  15 / 17  radius =  0.0001
# iter  16 / 17  radius =  0.0001
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  1.0
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.0625
# iter  6 / 17  radius =  0.03125
# iter  7 / 17  radius =  0.015625
# iter  8 / 17  radius =  0.0078125
# iter  9 / 17  radius =  0.00390625
# iter  10 / 17  radius =  0.001953125
# iter  11 / 17  radius =  0.0009765625
# iter  12 / 17  radius =  0.00048828125
# iter  13 / 17  radius =  0.000244140625
# iter  14 / 17  radius =  0.0001220703125
# iter  15 / 17  radius =  0.0001
# iter  16 / 17  radius =  0.0001
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.0625
# iter  6 / 17  radius =  0.03125
# iter  7 / 17  radius =  0.0625
# iter  8 / 17  radius =  0.03125
# iter  9 / 17  radius =  0.015625
# iter  10 / 17  radius =  0.0078125
# iter  11 / 17  radius =  0.00390625
# iter  12 / 17  radius =  0.001953125
# iter  13 / 17  radius =  0.0009765625
# iter  14 / 17  radius =  0.00048828125
# iter  15 / 17  radius =  0.000244140625
# iter  16 / 17  radius =  0.0001220703125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  1.0
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  2.0
# iter  7 / 17  radius =  4.0
# iter  8 / 17  radius =  8.0
# iter  9 / 17  radius =  16.0
# iter  10 / 17  radius =  32.0
# iter  11 / 17  radius =  64.0
# iter  12 / 17  radius =  128.0
# iter  13 / 17  radius =  256.0
# iter  14 / 17  radius =  512.0
# iter  15 / 17  radius =  1024.0
# iter  16 / 17  radius =  2048.0
# =====================  Antonio_f D2
# ==  LS_QM_v2
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.25
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.125
# iter  11 / 17  radius =  0.0625
# iter  12 / 17  radius =  0.03125
# iter  13 / 17  radius =  0.015625
# iter  14 / 17  radius =  0.0078125
# iter  15 / 17  radius =  0.00390625
# iter  16 / 17  radius =  0.001953125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.125
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.125
# iter  11 / 17  radius =  0.25
# iter  12 / 17  radius =  0.125
# iter  13 / 17  radius =  0.25
# iter  14 / 17  radius =  0.5
# iter  15 / 17  radius =  0.25
# iter  16 / 17  radius =  0.125
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  1.0
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.5
# iter  5 / 17  radius =  1.0
# iter  6 / 17  radius =  2.0
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.125
# iter  11 / 17  radius =  0.0625
# iter  12 / 17  radius =  0.125
# iter  13 / 17  radius =  0.25
# iter  14 / 17  radius =  0.5
# iter  15 / 17  radius =  1.0
# iter  16 / 17  radius =  2.0
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  0.25
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  1.0
# iter  4 / 17  radius =  2.0
# iter  5 / 17  radius =  4.0
# iter  6 / 17  radius =  8.0
# iter  7 / 17  radius =  4.0
# iter  8 / 17  radius =  2.0
# iter  9 / 17  radius =  1.0
# iter  10 / 17  radius =  2.0
# iter  11 / 17  radius =  4.0
# iter  12 / 17  radius =  8.0
# iter  13 / 17  radius =  4.0
# iter  14 / 17  radius =  8.0
# iter  15 / 17  radius =  16.0
# iter  16 / 17  radius =  32.0
# iter  0 / 17  radius =  0.5
# iter  1 / 17  radius =  1.0
# iter  2 / 17  radius =  0.5
# iter  3 / 17  radius =  0.25
# iter  4 / 17  radius =  0.125
# iter  5 / 17  radius =  0.25
# iter  6 / 17  radius =  0.5
# iter  7 / 17  radius =  1.0
# iter  8 / 17  radius =  0.5
# iter  9 / 17  radius =  0.25
# iter  10 / 17  radius =  0.5
# iter  11 / 17  radius =  0.25
# iter  12 / 17  radius =  0.125
# iter  13 / 17  radius =  0.0625
# iter  14 / 17  radius =  0.03125
# iter  15 / 17  radius =  0.015625
# iter  16 / 17  radius =  0.0078125
# =====================  Levy_f D5
# ==  LS_QM_v2
# iter  0 / 44  radius =  0.5
# iter  1 / 44  radius =  1.0
# iter  2 / 44  radius =  0.5
# iter  3 / 44  radius =  0.25
# iter  4 / 44  radius =  0.125
# iter  5 / 44  radius =  0.0625
# iter  6 / 44  radius =  0.03125
# iter  7 / 44  radius =  0.015625
# iter  8 / 44  radius =  0.0078125
# iter  9 / 44  radius =  0.00390625
# iter  10 / 44  radius =  0.001953125
# iter  11 / 44  radius =  0.0009765625
# iter  12 / 44  radius =  0.00048828125
# iter  13 / 44  radius =  0.000244140625
# iter  14 / 44  radius =  0.0001220703125
# iter  15 / 44  radius =  0.0001
# iter  16 / 44  radius =  0.0001
# iter  17 / 44  radius =  0.0001
# iter  18 / 44  radius =  0.0001
# iter  19 / 44  radius =  0.0001
# iter  20 / 44  radius =  0.0001
# iter  21 / 44  radius =  0.0001
# iter  22 / 44  radius =  0.0001
# iter  23 / 44  radius =  0.0001
# iter  24 / 44  radius =  0.0001
# iter  25 / 44  radius =  0.0001
# iter  26 / 44  radius =  0.0001
# iter  27 / 44  radius =  0.0001
# iter  28 / 44  radius =  0.0001
# iter  29 / 44  radius =  0.0001
# iter  30 / 44  radius =  0.0001
# iter  31 / 44  radius =  0.0001
# iter  32 / 44  radius =  0.0001
# iter  33 / 44  radius =  0.0001
# iter  34 / 44  radius =  0.0001
# iter  35 / 44  radius =  0.0001
# iter  36 / 44  radius =  0.0001
# iter  37 / 44  radius =  0.0001
# iter  38 / 44  radius =  0.0001
# iter  39 / 44  radius =  0.0001
# iter  40 / 44  radius =  0.0001
# iter  41 / 44  radius =  0.0001
# iter  42 / 44  radius =  0.0001
# iter  43 / 44  radius =  0.0001
# iter  0 / 44  radius =  0.5
# iter  1 / 44  radius =  0.25
# iter  2 / 44  radius =  0.125
# iter  3 / 44  radius =  0.0625
# iter  4 / 44  radius =  0.03125
# iter  5 / 44  radius =  0.0625
# iter  6 / 44  radius =  0.125
# iter  7 / 44  radius =  0.0625
# iter  8 / 44  radius =  0.03125
# iter  9 / 44  radius =  0.015625
# iter  10 / 44  radius =  0.0078125
# iter  11 / 44  radius =  0.00390625
# iter  12 / 44  radius =  0.001953125
# iter  13 / 44  radius =  0.0009765625
# iter  14 / 44  radius =  0.00048828125
# iter  15 / 44  radius =  0.000244140625
# iter  16 / 44  radius =  0.00048828125
# iter  17 / 44  radius =  0.000244140625
# iter  18 / 44  radius =  0.0001220703125
# iter  19 / 44  radius =  0.0001
# iter  20 / 44  radius =  0.0001
# iter  21 / 44  radius =  0.0002
# iter  22 / 44  radius =  0.0004
# iter  23 / 44  radius =  0.0008
# iter  24 / 44  radius =  0.0016
# iter  25 / 44  radius =  0.0032
# iter  26 / 44  radius =  0.0064
# iter  27 / 44  radius =  0.0128
# iter  28 / 44  radius =  0.0256
# iter  29 / 44  radius =  0.0512
# iter  30 / 44  radius =  0.1024
# iter  31 / 44  radius =  0.2048
# iter  32 / 44  radius =  0.1024
# iter  33 / 44  radius =  0.0512
# iter  34 / 44  radius =  0.0256
# iter  35 / 44  radius =  0.0128
# iter  36 / 44  radius =  0.0064
# iter  37 / 44  radius =  0.0032
# iter  38 / 44  radius =  0.0016
# iter  39 / 44  radius =  0.0008
# iter  40 / 44  radius =  0.0004
# iter  41 / 44  radius =  0.0002
# iter  42 / 44  radius =  0.0001
# iter  43 / 44  radius =  0.0001
# iter  0 / 44  radius =  0.5
# iter  1 / 44  radius =  0.25
# iter  2 / 44  radius =  0.125
# iter  3 / 44  radius =  0.0625
# iter  4 / 44  radius =  0.125
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\utils.py:136, in ML4CE_uncon_eval(N_x_l, f_eval_l, functions_test, algorithms_test, reps, home_dir, SafeData)
#     133 t_       = Test_function(i_function, N_x_, False, x_shift_)
#     134 # algorithm
#     135 # a, b, team_names, cids = i_algorithm(t_.fun_test, N_x_, bounds_, f_eval_)
# --> 136 a, b, team_names, cids = i_algorithm(t_, N_x_, bounds_, f_eval_)
#     137 # post-processing
#     138 t_.best_f_list()                    # List of best points so far
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:323, in LS_QM_v2(f, x_dim, bounds, iter_tot, x_start)
#     320 r_t = max(r_t,10e-5)
#     322 # === re-Estimate quadratic model === #
# --> 323 LSQM_m = Quad_Reg_model(x_list[:n_rs+iter_i+1,:],
#     324                         f_list[:n_rs+iter_i+1].reshape(-1,1),
#     325                         x_best)
#     327 # check that f_best corresponds to x_best otherwise there is something strange
#     328 # check
#     329 minindex_ = np.argmin(f_list)
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:55, in Quad_Reg_model.__init__(self, X, Y, x_centre)
#      53 hyp_init    = lb + (ub-lb)*multi_startvec[j,:]
#      54 # --- hyper-parameter optimization --- #
# ---> 55 res = minimize(self.LS, hyp_init, args=(self.X_norm,self.Y_norm),method='SLSQP',
#      56                bounds=bounds)
#      57 localsol[j] = res.x
#      58 localval[j] = res.fun
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
# --> 722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
#     725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_slsqp_py.py:441, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     438     c = _eval_constraint(x, cons)
#     440 if mode == -1:  # gradient evaluation required
# --> 441     g = append(wrapped_grad(x), 0.0)
#     442     a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     444 if majiter > majiter_prev:
#     445     # call callback if major iteration has incremented
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:302, in _clip_x_for_func.<locals>.eval(x)
#     300 def eval(x):
#     301     x = _check_clip_x(x, bounds)
# --> 302     return func(x)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:284, in ScalarFunction.grad(self, x)
#     282 if not np.array_equal(x, self.x):
#     283     self._update_x_impl(x)
# --> 284 self._update_grad()
#     285 return self.g
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:107, in Quad_Reg_model.LS(self, pOpt, Xdat, Ydat)
#     104 X_d            = X_d.reshape(Yw.shape)
#     106 # Y prediction
# --> 107 Y_pred = self.predict_dataset(Xdat, Qp_,cp_,dp_)
#     108 Y_pred = Y_pred.reshape(Ydat.shape)
#     111 # least-squares == notice the weight (Yw+1e-2+X_d) and regularization
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:125, in Quad_Reg_model.predict_dataset(self, Xdat, Qp, cp, dp)
#     121 def predict_dataset(self, Xdat, Qp,cp,dp):
#     122     '''
#     123     Predicts Ydat based on dataset Xdat
#     124     '''
# --> 125     Ypred = np.sum(Xdat * np.dot(Xdat,Qp), axis=(1)) + cp@Xdat.T + dp
#     127     return Ypred
#
# KeyboardInterrupt:

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\Coursework1_DDO\benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-04-15_07-43-43\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# %% [markdown]
# ### Plot performance tables

# %%
array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)

# %%
timestamp = '2024-04-15_07-43-43'

# %%
ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = False)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=True)
