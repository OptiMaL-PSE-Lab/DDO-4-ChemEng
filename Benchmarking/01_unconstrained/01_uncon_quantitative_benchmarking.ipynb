# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search import*
from Cuadratic_opt_v2 import *
from Scipy_opt_algs import*
from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from ScikitQuant_opt_algs import *
from pySOT_opt_algs import *
from CUATRO import *
from ENTMOOT import *


##########################
# Algorithms & Functions #
##########################



algorithms_test = [
    LS_QM_v2,
    opt_SnobFit,
    opt_SRBF,
    opt_DYCORS,
    opt_SOP,
    opt_COBYLA,
    COBYQA,
    opt_CUATRO,
    BO_np_scipy,
    opt_ENTMOOT,
    ]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

###########################
# Optimization parameters #
###########################

N_x_l        = [
    2,
    5,
    7,
    ]               # Number of input dimensions

start_       = [5, 10, 15]              # starting points on the trajectory of the algorithm on the test function

reps         = 1                        # We run each algorithm 5 times on each objective function. The number of evaluations per run is given by f_eval_l
f_eval_l     = [
    20,
    50,
    100
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

home_dir  = 'images/trajectory_plots_1D_&_tables'
SaveData = False

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  Levy_f D2
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]
# im here
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# 100%|██████████| 17/17 [00:01<00:00,  9.06it/s]
# 100%|██████████| 1/1 [00:02<00:00,  2.15s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00, 12.06it/s]
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00, 13.90it/s]
# ==  opt_DYCORS
# 100%|██████████| 1/1 [00:00<00:00, 14.80it/s]
# ==  opt_SOP
# 100%|██████████| 1/1 [00:00<00:00, 12.09it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 501.71it/s]
# ==  COBYQA
# 100%|██████████| 1/1 [00:00<00:00, 13.83it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 2.6698905978321443
# TR update: iteration 1, objective 2.670, evaluation 7
# 0.7400014381431721
# TR update: iteration 2, objective 0.740, evaluation 12
# 0.1719123664472509
# TR update: iteration 3, objective 0.172, evaluation 15
# 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 17/17 [00:08<00:00,  2.08it/s]
# 100%|██████████| 1/1 [00:08<00:00,  8.27s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# Set parameter Username
# Academic license - for non-commercial use only - expires 2025-05-22
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:05<00:00,  5.54s/it]
# =====================  Ackley_f D2
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# im here
# 100%|██████████| 17/17 [00:02<00:00,  5.77it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.07s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00, 10.34it/s]
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00, 12.23it/s]
# ==  opt_DYCORS
# 100%|██████████| 1/1 [00:00<00:00, 12.05it/s]
# ==  opt_SOP
# 100%|██████████| 1/1 [00:00<00:00, 11.98it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 1002.70it/s]
# ==  COBYQA
# 100%|██████████| 1/1 [00:00<00:00, 17.78it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 11.363122695535061
# TR update: iteration 1, objective 11.363, evaluation 7
# 9.47761443687749
# TR update: iteration 2, objective 9.478, evaluation 13
# 100%|██████████| 1/1 [00:00<00:00,  3.31it/s]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 17/17 [00:06<00:00,  2.57it/s]
# 100%|██████████| 1/1 [00:06<00:00,  6.72s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:04<00:00,  4.09s/it]
# =====================  Rosenbrock_f D2
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# remember to reset the starting values in test function
# im here
# 100%|██████████| 17/17 [00:01<00:00, 11.54it/s]
# 100%|██████████| 1/1 [00:01<00:00,  1.57s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00, 14.28it/s]
# remember to reset the starting values in test function
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00, 15.23it/s]
# remember to reset the starting values in test function
# ==  opt_DYCORS
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# 100%|██████████| 1/1 [00:00<00:00, 12.99it/s]
# ==  opt_SOP
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# 100%|██████████| 1/1 [00:00<00:00,  8.88it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 1040.25it/s]
# remember to reset the starting values in test function
# ==  COBYQA
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# 100%|██████████| 1/1 [00:00<00:00, 10.44it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# remember to reset the starting values in test function
# 100%|██████████| 1/1 [00:00<00:00,  4.51it/s]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 17/17 [00:10<00:00,  1.69it/s]
# 100%|██████████| 1/1 [00:10<00:00, 10.18s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# remember to reset the starting values in test function
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:03<00:00,  3.54s/it]
# =====================  Antonio_f D2
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# im here
# 100%|██████████| 17/17 [00:03<00:00,  4.40it/s]
# 100%|██████████| 1/1 [00:03<00:00,  3.99s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00, 14.25it/s]
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00, 15.46it/s]
# ==  opt_DYCORS
# 100%|██████████| 1/1 [00:00<00:00, 14.85it/s]
# ==  opt_SOP
# 100%|██████████| 1/1 [00:00<00:00, 11.64it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 492.75it/s]
# ==  COBYQA
# 100%|██████████| 1/1 [00:00<00:00, 10.50it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 103.95692961055335
# TR update: iteration 1, objective 103.957, evaluation 7
# 63.586019308946135
# TR update: iteration 2, objective 63.586, evaluation 12
# 100%|██████████| 1/1 [00:00<00:00,  4.57it/s]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# - No preliminar data supplied, computing data by sobol sequence
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 17/17 [00:09<00:00,  1.71it/s]
# 100%|██████████| 1/1 [00:10<00:00, 10.05s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:03<00:00,  3.98s/it]
# =====================  Levy_f D5
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# im here
# 100%|██████████| 44/44 [00:34<00:00,  1.29it/s]
# 100%|██████████| 1/1 [00:34<00:00, 34.67s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00,  6.71it/s]
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00,  4.01it/s]
# ==  opt_DYCORS
# 100%|██████████| 1/1 [00:00<00:00,  4.69it/s]
# ==  opt_SOP
# 100%|██████████| 1/1 [00:00<00:00,  2.79it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 330.75it/s]
# ==  COBYQA
# 100%|██████████| 1/1 [00:00<00:00,  4.19it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 8.104761392566177
# TR update: iteration 4, objective 8.105, evaluation 25
# 7.3414536110213255
# TR update: iteration 5, objective 7.341, evaluation 29
# 100%|██████████| 1/1 [00:01<00:00,  1.73s/it]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 44/44 [02:13<00:00,  3.03s/it]
# 100%|██████████| 1/1 [02:13<00:00, 133.26s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# 100%|██████████| 1/1 [00:34<00:00, 34.09s/it]
# =====================  Ackley_f D5
# ==  LS_QM_v2
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\stats\_qmc.py:804: UserWarning: The balance properties of Sobol' points require n to be a power of 2.
#   sample = self._random(n, workers=workers)
# im here
# 100%|██████████| 44/44 [00:36<00:00,  1.20it/s]
# 100%|██████████| 1/1 [00:37<00:00, 37.05s/it]
# ==  opt_SnobFit
# 100%|██████████| 1/1 [00:00<00:00,  6.92it/s]
# ==  opt_SRBF
# 100%|██████████| 1/1 [00:00<00:00,  4.27it/s]
# ==  opt_DYCORS
# 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# ==  opt_SOP
# 100%|██████████| 1/1 [00:00<00:00,  2.73it/s]
# ==  opt_COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 331.36it/s]
# ==  COBYQA
# 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# ==  opt_CUATRO
#   0%|          | 0/1 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 12.945529399818358
# TR update: iteration 1, objective 12.946, evaluation 7
# 12.531281569941827
# TR update: iteration 4, objective 12.531, evaluation 25
# 12.274867405114927
# TR update: iteration 5, objective 12.275, evaluation 29
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# 11.985630939898785
# TR update: iteration 7, objective 11.986, evaluation 39
# 100%|██████████| 1/1 [00:01<00:00,  1.15s/it]
# ==  BO_np_scipy
#   0%|          | 0/1 [00:00<?, ?it/s]
# - No preliminar data supplied, computing data by sobol sequence
# 100%|██████████| 44/44 [02:13<00:00,  3.03s/it]
# 100%|██████████| 1/1 [02:13<00:00, 133.47s/it]
# ------------------------------------FINISH-----------------------------------------
# ==  opt_ENTMOOT
#   0%|          | 0/1 [00:00<?, ?it/s]
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0
# Set parameter MIPGap to value 0

# %% [markdown]
# ### Benchmark

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-06-11_18-46-16\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-06-11_18-46-16'

# %% [markdown]
# ### Plot performance tables

# %%
# array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, multim, N_x_l, start_)

# %%
# ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = SaveData)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=SaveData)

# %%
# ML4CE_uncon_graph_rel(trajectories, algorithms_test, functions_test, N_x_l)
