# %% [markdown]
# This is a purely qualitative analysis. This is why this part is detached from the "benchmarking.ipynb". It does its own 2D "benchmarking" but rather to produce the trajectory points that go into the 2D contour plots. The trajectories seen here should qualitatively represent the ones in the benchmarking, however they are not actual runs that went into the performance tables.

# %% [markdown]
# ### Imports

# %%
# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
from BFGS_multistart import*
from Stochastic_local_search_plot import*
from Cuadratic_opt import*
from Cuadratic_opt_v2 import*
from Scipy_opt_algs import*
from BO_NpScpy import*
from COBYQA import*
# importing test functions
from test_function import*
from utils import *

# %% [markdown]
# ### Basic lists and values

# %%
algorithms_test = [
    LS_QM_v2, # TODO this needs to be updated to take an initial point, also for the qualitative benchmarking
#     opt_COBYLA,
#     COBYQA,
# # # Feel free to add these commented-out algorithms as a further test,
# # # however, do note they are more time-consuming to run
# BO_np_scipy
]

functions_test  = [  #!!! Multimodal before Unimodal!!!
    'Levy_f',
    'Ackley_f',
    'Rosenbrock_f',
    'Antonio_f',
    ]

multim  = ['Levy_f', 'Ackley_f']
unim    = ['Rosenbrock_f', 'Antonio_f']

# no. input dimensions
N_x_ = 2

# repetition for random shift
i_rep = 0
reps         = 5
# randShift_l = np.random.uniform(-3,3, (reps,N_x_))
# x_shift_ = randShift_l[i_rep,:].reshape((N_x_,1))

# trajectory length (= evaluation budget)
f_eval_ = 40

# bounds and other settings
track_x = True
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function
bounds_ = np.array([[-5., 5.], [-5., 5.]]) # x1 bounds, x2 bounds these are taken from the benchmarking routine
bounds_plot = np.array([[-5, 5], [-5, 5]]) 
samples_number = 10 # for BO

# %% [markdown]
# ### Run 2 dimensional and plot trajectory

# %%
for fun_ in functions_test:
    for alg_ in algorithms_test:
        t_ = Test_function(fun_, N_x_, track_x, x_shift_origin)
        print(alg_)
        a, b, team_names, cids = alg_(t_, N_x_, bounds_, f_eval_,x_start=False)
        X_opt = np.array(t_.x_list)
        ML4CE_uncon_contours(t_, alg_, bounds_plot, X_opt, X_opt[-1], samples_number, fun_, SafeFig=False)
# Out:
# <function LS_QM_v2 at 0x0000013FEB8ED6C0>
# iter  0 / 37  radius =  0.5
# iter  1 / 37  radius =  0.25
# iter  2 / 37  radius =  0.5
# iter  3 / 37  radius =  0.25
# iter  4 / 37  radius =  0.5
# iter  5 / 37  radius =  0.25
# iter  6 / 37  radius =  0.125
# iter  7 / 37  radius =  0.0625
# iter  8 / 37  radius =  0.03125
# iter  9 / 37  radius =  0.015625
# iter  10 / 37  radius =  0.0078125
# iter  11 / 37  radius =  0.00390625
# iter  12 / 37  radius =  0.001953125
# iter  13 / 37  radius =  0.0009765625
# iter  14 / 37  radius =  0.00048828125
# iter  15 / 37  radius =  0.000244140625
# iter  16 / 37  radius =  0.0001220703125
# iter  17 / 37  radius =  0.0001
# iter  18 / 37  radius =  0.0001
# iter  19 / 37  radius =  0.0001
# iter  20 / 37  radius =  0.0001
.0001
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 t_ = Test_function(fun_, N_x_, track_x, x_shift_origin)
#       4 print(alg_)
# ----> 5 a, b, team_names, cids = alg_(t_, N_x_, bounds_, f_eval_,x_start=False)
#       6 X_opt = np.array(t_.x_list)
#       7 ML4CE_uncon_contours(t_, alg_, bounds_plot, X_opt, X_opt[-1], samples_number, fun_, SafeFig=False)
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:323, in LS_QM_v2(f, x_dim, bounds, iter_tot, x_start)
#     320 r_t = max(r_t,10e-5)
#     322 # === re-Estimate quadratic model === #
# --> 323 LSQM_m = Quad_Reg_model(x_list[:n_rs+iter_i+1,:],
#     324                         f_list[:n_rs+iter_i+1].reshape(-1,1),
#     325                         x_best)
#     327 # check that f_best corresponds to x_best otherwise there is something strange
#     328 # check
#     329 minindex_ = np.argmin(f_list)
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:55, in Quad_Reg_model.__init__(self, X, Y, x_centre)
#      53 hyp_init    = lb + (ub-lb)*multi_startvec[j,:]
#      54 # --- hyper-parameter optimization --- #
# ---> 55 res = minimize(self.LS, hyp_init, args=(self.X_norm,self.Y_norm),method='SLSQP',
#      56                bounds=bounds)
#      57 localsol[j] = res.x
#      58 localval[j] = res.fun
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_minimize.py:722, in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     719     res = _minimize_cobyla(fun, x0, args, constraints, callback=callback,
#     720                            bounds=bounds, **options)
#     721 elif meth == 'slsqp':
# --> 722     res = _minimize_slsqp(fun, x0, args, jac, bounds,
#     723                           constraints, callback=callback, **options)
#     724 elif meth == 'trust-constr':
#     725     res = _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#     726                                        bounds, constraints,
#     727                                        callback=callback, **options)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_slsqp_py.py:441, in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, finite_diff_rel_step, **unknown_options)
#     438     c = _eval_constraint(x, cons)
#     440 if mode == -1:  # gradient evaluation required
# --> 441     g = append(wrapped_grad(x), 0.0)
#     442     a = _eval_con_normals(x, cons, la, n, m, meq, mieq)
#     444 if majiter > majiter_prev:
#     445     # call callback if major iteration has incremented
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:302, in _clip_x_for_func.<locals>.eval(x)
#     300 def eval(x):
#     301     x = _check_clip_x(x, bounds)
# --> 302     return func(x)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:284, in ScalarFunction.grad(self, x)
#     282 if not np.array_equal(x, self.x):
#     283     self._update_x_impl(x)
# --> 284 self._update_grad()
#     285 return self.g
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:267, in ScalarFunction._update_grad(self)
#     265 def _update_grad(self):
#     266     if not self.g_updated:
# --> 267         self._update_grad_impl()
#     268         self.g_updated = True
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:181, in ScalarFunction.__init__.<locals>.update_grad()
#     179 self._update_fun()
#     180 self.ngev += 1
# --> 181 self.g = approx_derivative(fun_wrapped, self.x, f0=self.f,
#     182                            **finite_diff_options)
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:519, in approx_derivative(fun, x0, method, rel_step, abs_step, f0, bounds, sparsity, as_linear_operator, args, kwargs)
#     516     use_one_sided = False
#     518 if sparsity is None:
# --> 519     return _dense_difference(fun_wrapped, x0, f0, h,
#     520                              use_one_sided, method)
#     521 else:
#     522     if not issparse(sparsity) and len(sparsity) == 2:
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:590, in _dense_difference(fun, x0, f0, h, use_one_sided, method)
#     588     x = x0 + h_vecs[i]
#     589     dx = x[i] - x0[i]  # Recompute dx as exactly representable number.
# --> 590     df = fun(x) - f0
#     591 elif method == '3-point' and use_one_sided[i]:
#     592     x1 = x0 + h_vecs[i]
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_numdiff.py:470, in approx_derivative.<locals>.fun_wrapped(x)
#     467 if xp.isdtype(x.dtype, "real floating"):
#     468     x = xp.astype(x, x0.dtype)
# --> 470 f = np.atleast_1d(fun(x, *args, **kwargs))
#     471 if f.ndim > 1:
#     472     raise RuntimeError("`fun` return value has "
#     473                        "more than 1 dimension.")
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_differentiable_functions.py:145, in ScalarFunction.__init__.<locals>.fun_wrapped(x)
#     141 self.nfev += 1
#     142 # Send a copy because the user may overwrite it.
#     143 # Overwriting results in undefined behaviour because
#     144 # fun(self.x) will change self.x, with the two no longer linked.
# --> 145 fx = fun(np.copy(x), *args)
#     146 # Make sure the function returns a true scalar
#     147 if not np.isscalar(fx):
#
# File c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\Cuadratic_opt_v2.py:99, in Quad_Reg_model.LS(self, pOpt, Xdat, Ydat)
#      97 Qp_.T[indices] = symmVect
#      98 Qp_            = Qp_@Qp_.T
# ---> 99 Qp_            = Qp_ + np.eye(nx_dim)*np.matrix.trace(Qp_)/nx_dim
#     100 # penalty on objective function value
#     101 Yw             = Ydat + np.abs(np.min(Ydat))
#
# File c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\numpy\lib\twodim_base.py:158, in eye(N, M, k, dtype, order, like)
#     154         raise ValueError("Input must be >= 1-d.")
#     155     return m[::-1, ...]
# --> 158 @set_array_function_like_doc
#     159 @set_module('numpy')
#     160 def eye(N, M=None, k=0, dtype=float, order='C', *, like=None):
#     161     """
#     162     Return a 2-D array with ones on the diagonal and zeros elsewhere.
#     163
#    (...)
#     205
#     206     """
#     207     if like is not None:
#
# KeyboardInterrupt:
