# %%
###########
# Imports #
###########

# importing libraries
import matplotlib.pyplot as plt
import copy
# importing algorithms
#from BFGS_multistart import*
#from Stochastic_local_search import*
#from Cuadratic_opt_v2 import *
#from Scipy_opt_algs import*
#from BO_NpScpy import*
# importing test functions
from test_function import*
from utils import *
from COBYQA import *
from opt_GPyOpt import *
#from ScikitQuant_opt_algs import *
#from pySOT_opt_algs import *
#from CUATRO import *
#from ENTMOOT import *

from CSTR_PID import *

##########################
# Algorithms & Functions #
##########################

home_dir  = 'images/trajectory_plots_1D_&_tables'

algorithms_test = [
    # LS_QM_v2,
    # opt_SnobFit,
    # opt_SRBF,
    # opt_DYCORS,
    # opt_SOP,
    opt_COBYLA,
    GPyOpt_BO,
    #COBYQA,
    # opt_CUATRO,
    # BO_np_scipy,
    # opt_ENTMOOT,
    ]

functions_test  = ['cstr_pid_f']


###########################
# Optimization parameters #
###########################

N_x_l        = [32]               # Number of input dimensions

start_       = [5, 10, 15]        # starting points on the trajectory of the algorithm on the test function

reps         = 2                  

f_eval_l     = [20, 50, 100]      # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

# %%
info, trajectories, timestamp = ML4CE_uncon_eval(N_x_l,f_eval_l,functions_test,algorithms_test,reps, home_dir, SafeData = False)
# Out:
# =====================  cstr_pid_f D32
# ==  opt_COBYLA
# ==  GPyOpt_BO

# %% [markdown]
# ### Benchmark

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\images\trajectory_plots_1D_&_tables\2024-06-11_18-46-16\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-06-11_18-46-16'

# %% [markdown]
# ### Plot performance tables

# %%
array = ML4CE_uncon_table(trajectories,algorithms_test,functions_test, 'cstr_pid_f', N_x_l, start_)
# Out:
# ==   opt_COBYLA  ==
# ==   GPyOpt_BO  ==

# %%
ML4CE_uncon_table_plot(array, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = False)

# %% [markdown]
# ### Plot graphs

# %%
ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 ML4CE_uncon_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=True)
#
# File c:\Users\Emma\Documents\DDO Book Chapter\DDO-4-ChemEng\Benchmarking\01_unconstrained\utils.py:427, in ML4CE_uncon_graph_abs(test_res, algs_test, funcs_test, N_x_l, home_dir, timestamp, SafeFig)
#     425 # plt.yscale('log')
#     426 plt.legend(loc='best', prop={'family':'Times New Roman', 'size': 24})
# --> 427 plt.tick_params(axis='x', labelsize=24, labelcolor='black', labelfontfamily='Times New Roman')  # Set size and font name of x ticks
#     428 plt.tick_params(axis='y', labelsize=24, labelcolor='black', labelfontfamily='Times New Roman')  # Set size and font name of y ticks
#     429 # plt.title(funcs_test[i_fun] + ' ' + dim_S + ' convergence plot')
#     430 # grid(True)
#
# File c:\Users\Emma\anaconda3\envs\safeopt_env\lib\site-packages\matplotlib\pyplot.py:2919, in tick_params(axis, **kwargs)
#    2917 @_copy_docstring_and_deprecators(Axes.tick_params)
#    2918 def tick_params(axis='both', **kwargs):
# -> 2919     return gca().tick_params(axis=axis, **kwargs)
#
# File c:\Users\Emma\anaconda3\envs\safeopt_env\lib\site-packages\matplotlib\axes\_base.py:3428, in _AxesBase.tick_params(self, axis, **kwargs)
#    3426     xkw.pop('labelleft', None)
#    3427     xkw.pop('labelright', None)
# -> 3428     self.xaxis.set_tick_params(**xkw)
#    3429 if axis in ['y', 'both']:
#    3430     ykw = dict(kwargs)
#
# File c:\Users\Emma\anaconda3\envs\safeopt_env\lib\site-packages\matplotlib\axis.py:925, in Axis.set_tick_params(self, which, reset, **kwargs)
#     918 """
#     919 Set appearance parameters for ticks, ticklabels, and gridlines.
#     920
#     921 For documentation of keyword arguments, see
#     922 :meth:`matplotlib.axes.Axes.tick_params`.
#     923 """
#     924 _api.check_in_list(['major', 'minor', 'both'], which=which)
# --> 925 kwtrans = self._translate_tick_params(kwargs)
#     927 # the kwargs are stored in self._major/minor_tick_kw so that any
#     928 # future new ticks will automatically get them
#     929 if reset:
#
# File c:\Users\Emma\anaconda3\envs\safeopt_env\lib\site-packages\matplotlib\axis.py:1004, in Axis._translate_tick_params(kw)
#    1002 for key in kw:
#    1003     if key not in allowed_keys:
# -> 1004         raise ValueError(
#    1005             "keyword %s is not recognized; valid keywords are %s"
#    1006             % (key, allowed_keys))
#    1007 kwtrans.update(kw)
#    1008 return kwtrans
#
# ValueError: keyword labelfontfamily is not recognized; valid keywords are ['size', 'width', 'color', 'tickdir', 'pad', 'labelsize', 'labelcolor', 'zorder', 'gridOn', 'tick1On', 'tick2On', 'label1On', 'label2On', 'length', 'direction', 'left', 'bottom', 'right', 'top', 'labelleft', 'labelbottom', 'labelright', 'labeltop', 'labelrotation', 'grid_agg_filter', 'grid_alpha', 'grid_animated', 'grid_antialiased', 'grid_clip_box', 'grid_clip_on', 'grid_clip_path', 'grid_color', 'grid_dash_capstyle', 'grid_dash_joinstyle', 'grid_dashes', 'grid_data', 'grid_drawstyle', 'grid_figure', 'grid_fillstyle', 'grid_gapcolor', 'grid_gid', 'grid_in_layout', 'grid_label', 'grid_linestyle', 'grid_linewidth', 'grid_marker', 'grid_markeredgecolor', 'grid_markeredgewidth', 'grid_markerfacecolor', 'grid_markerfacecoloralt', 'grid_markersize', 'grid_markevery', 'grid_mouseover', 'grid_path_effects', 'grid_picker', 'grid_pickradius', 'grid_rasterized', 'grid_sketch_params', 'grid_snap', 'grid_solid_capstyle', 'grid_solid_joinstyle', 'grid_transform', 'grid_url', 'grid_visible', 'grid_xdata', 'grid_ydata', 'grid_zorder', 'grid_aa', 'grid_c', 'grid_ds', 'grid_ls', 'grid_lw', 'grid_mec', 'grid_mew', 'grid_mfc', 'grid_mfcalt', 'grid_ms']

# %%
# ML4CE_uncon_graph_rel(trajectories, algorithms_test, functions_test, N_x_l)
