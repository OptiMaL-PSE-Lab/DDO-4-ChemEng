# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *

# %%
algorithms_test = [
    # CBO_opt,          # gets f_eval which is set to 40 here, then subtracts the initial samples which is 10 which leaves 30 iterations for the algorithm
    # CBO_TR_opt,
    COBYLA,         # one less iteration in f_list than in g_list because of the staritng point. This means g
    # COBYQA,         # matches exactly
    # opt_CUATRO, 
]

functions_test  = [
    'WO_f',
    ]

N_x_l        = [
    2,
    ]               # Number of input dimensions

start_       = [5, 10, 15] # we start counting the last 15 points / 40 points / 85 points from each trajectory instead of all of them

reps         = 1


bounds  = np.array([[4., 7.], [70., 100.]])
home_dir  = 'images/WO/trajectory_plots_1D_&_tables'
track_x = True
N_x_ = 2
i_rep = 0
TR_plot = False
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function
SafeData = True

# %%
# for alg_ in algorithms_test:
#     for func_ in functions_test:
#         t_ = Test_function(func_, n_x=2, track_x=track_x)
#         a, b, team_names, cids, X_opt_plot, TR_l, xnew, backtrck_l, samples_number = alg_(t_, N_x_, bounds, f_eval_, i_rep)
#         ML4CE_con_contours(t_, alg_, bounds, X_opt_plot, xnew, samples_number, func_, TR_plot, TR_l, SafeFig = False)

# %%
ML4CE_con_contour_allin1(functions_test, algorithms_test, N_x_, x_shift_origin, bounds, i_rep, bounds_plot=bounds, directory_name=home_dir, SafeFig=SafeData)
# Out:
# <function COBYLA at 0x000001CA2B7B98A0>
# len f_list COBYLA
# 29
