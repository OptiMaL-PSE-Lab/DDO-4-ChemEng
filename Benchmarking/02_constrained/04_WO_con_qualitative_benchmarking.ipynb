# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *
# Out:
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:233: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i_function is not 'WO_f': trajectories[dim_S][i_function]['vio_g_values'][str(i_algorithm.__name__)].append([-t_.con_test(x) for x in X_all])
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:260: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if i_function is not 'WO_f':

# %%
algorithms_test = [
    CBO_opt,          # gets f_eval which is set to 40 here, then subtracts the initial samples which is 10 which leaves 30 iterations for the algorithm
    COBYLA,         # one less iteration in f_list than in g_list because of the staritng point. This means g
    COBYQA,         # matches exactly
    opt_CUATRO, 
]

functions_test  = [
    'WO_f',
    ]

N_x_l        = [
    2,
    ]               # Number of input dimensions

start_       = [5, 10, 15] # we start counting the last 15 points / 40 points / 85 points from each trajectory instead of all of them

reps         = 1


bounds  = np.array([[4., 7.], [70., 100.]])
bounds_plots_             = np.array([
    [[4,7],[70,100]], 
    ])
home_dir  = 'images/WO/trajectory_plots_2D'
track_x = True
N_x_ = 2
i_rep = 0
TR_plot = False
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function
SafeData = True

# %%
ML4CE_con_contour_allin1(functions_test, algorithms_test, N_x_, x_shift_origin, bounds, i_rep, bounds_plot=bounds_plots_, directory_name=home_dir, SafeFig=SafeData)
# Out:
# Text saved to 'INFO.txt' in folder 'images/WO/trajectory_plots_2D'.
# drawing contour
# 100%|██████████| 100/100 [00:40<00:00,  2.47it/s]
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:918: UserWarning: linewidths is ignored by contourf
#   contour = plt.contourf(X1, X2, y, levels=50, cmap='Spectral_r', alpha=0.5, linewidths=0.5)
# <function CBO_opt at 0x000001C5F3F1F420>
# 100%|██████████| 50/50 [08:18<00:00,  9.97s/it]
# <function COBYLA at 0x000001C5A2F27A60>
# <function COBYQA at 0x000001C5A327A160>
# <function opt_CUATRO at 0x000001C5A327B420>
# -2.908603466633622
# TR update: iteration 1, objective -2.909, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# -62.328629070321995
# TR update: iteration 2, objective -62.329, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\problems\problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# -69.3569922555572
# TR update: iteration 11, objective -69.357, evaluation 44

# %%
# ML4CE_con_contour_allin1(functions_test, algorithms_test, N_x_, x_shift_origin, bounds, i_rep, bounds_plot=bounds_plots_, directory_name=home_dir, SafeFig=SafeData)
