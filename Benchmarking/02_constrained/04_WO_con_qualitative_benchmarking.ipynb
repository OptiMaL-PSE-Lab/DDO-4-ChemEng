# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *

# %%
algorithms_test = [
    CBO_opt,          # gets f_eval which is set to 40 here, then subtracts the initial samples which is 10 which leaves 30 iterations for the algorithm
    COBYLA,         # one less iteration in f_list than in g_list because of the staritng point. This means g
    COBYQA,         # matches exactly
    opt_CUATRO, 
]

functions_test  = [
    'WO_f',
    ]

N_x_l        = [
    2,
    ]               # Number of input dimensions

start_       = [5, 10, 15] # we start counting the last 15 points / 40 points / 85 points from each trajectory instead of all of them

reps         = 1


bounds  = np.array([[4., 7.], [70., 100.]])
home_dir  = 'images/WO/trajectory_plots_2D'
track_x = True
N_x_ = 2
i_rep = 0
TR_plot = False
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function
SafeData = True

# %%
# for alg_ in algorithms_test:
#     for func_ in functions_test:
#         t_ = Test_function(func_, n_x=2, track_x=track_x)
#         a, b, team_names, cids, X_opt_plot, TR_l, xnew, backtrck_l, samples_number = alg_(t_, N_x_, bounds, f_eval_, i_rep)
#         ML4CE_con_contours(t_, alg_, bounds, X_opt_plot, xnew, samples_number, func_, TR_plot, TR_l, SafeFig = False)

# %%
ML4CE_con_contour_allin1(functions_test, algorithms_test, N_x_, x_shift_origin, bounds, i_rep, bounds_plot=bounds, directory_name=home_dir, SafeFig=SafeData)
# Out:
# Text saved to 'INFO' in folder 'images/WO/trajectory_plots_2D'.
# <function CBO_opt at 0x00000241DBF734C0>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 30/30 [02:16<00:00,  4.56s/it]
# ------------------------------------FINISH-----------------------------------------
# <function COBYLA at 0x00000241FFFA59E0>
# <function COBYQA at 0x00000241DBF731A0>
# <function opt_CUATRO at 0x000002418B2F5260>
# -2.908603466633622
# TR update: iteration 1, objective -2.909, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\problems\problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# -52.735595989822286
# TR update: iteration 3, objective -52.736, evaluation 18
# -68.69486432018607
# TR update: iteration 4, objective -68.695, evaluation 21
# -70.42763593310508
# TR update: iteration 10, objective -70.428, evaluation 34
# -71.24327374048801
# TR update: iteration 12, objective -71.243, evaluation 38
