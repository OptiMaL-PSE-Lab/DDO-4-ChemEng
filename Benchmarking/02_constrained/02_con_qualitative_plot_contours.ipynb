# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *

# %%
# These are now in the function
alg_list = [
    CBO_opt, # len_f = 92, len_g = 69, there are 11 starter points, for some reason in Matyas fkt nur 84
    COBYLA, # constrain evaluations are one more than function evaluations. The first 'none' in constraint evaluations has to be removed
    COBYQA, # constraint evaluations match function evaluations 
    opt_CUATRO # constraint evaluations match function evaluations 
]

N_x_ = 2                                                    # number of input dimensions

func_list = [
    # 'Rosenbrock_f',
    # 'Antonio_f',
    'Matyas_f',
]
i_rep = 0
reps = 10
track_x = True
# bounds_ = [[-5, 5],[-5, 5]] # x1 bounds, x2 bounds these are taken from the benchmarking routine
bounds_             = np.array([[-5,5] for i in range(N_x_)])
bounds_plots_             = np.array([
    # [[-5,3],[-2,5]], 
    # [[-5,3],[-5,3]], 
    [[-5,3],[-5,3]]
    ])
TR_plot       = False
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function

# for alg_ in alg_list:
#     for func_ in func_list:
#         t_ = Test_function(func_, n_x=N_x_, track_x=track_x)
#         a, b, team_names, cids, X_opt_plot, TR_l, xnew, backtrck_l, samples_number = alg_(t_, N_x_, bounds_, f_eval_, i_rep)
#         ML4CE_con_contours(t_, alg_, bounds_, X_opt_plot, xnew, samples_number, func_, TR_plot, TR_l, SafeFig = False)

DataSave = True
directory_name = 'images/trajectory_plots_2D'

# %%
# ML4CE_con_contour_allin1(func_list, alg_list, N_x_, x_shift_origin, bounds_, i_rep, bounds_plot=bounds_plots_, directory_name=directory_name, SafeFig=DataSave)

# %%
ML4CE_con_contour_allin1_smooth(func_list, alg_list, N_x_, x_shift_origin, bounds_, x0_in=0, reps=reps, bounds_plot=bounds_plots_, directory_name=directory_name, SafeFig=DataSave)
# Out:
# Text saved to 'INFO.txt' in folder 'images/trajectory_plots_2D'.
# drawing contour
# 100%|██████████| 100/100 [00:00<00:00, 2185.76it/s]
# repetition:  0
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:1124: UserWarning: linewidths is ignored by contourf
#   contour = plt.contourf(X1, X2, y, levels=50, cmap='Spectral_r', norm=norm, alpha=0.5, linewidths=0.5)
# 100%|██████████| 50/50 [04:28<00:00,  5.37s/it]
# repetition:  1
# 100%|██████████| 50/50 [04:43<00:00,  5.67s/it]
# repetition:  2
#  28%|██▊       | 14/50 [00:24<01:36,  2.69s/it]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 50/50 [05:03<00:00,  6.07s/it]
# repetition:  3
# 100%|██████████| 50/50 [05:14<00:00,  6.29s/it]
# repetition:  4
# 100%|██████████| 50/50 [04:54<00:00,  5.89s/it]
# repetition:  5
# 100%|██████████| 50/50 [04:50<00:00,  5.80s/it]
# repetition:  6
# 100%|██████████| 50/50 [04:54<00:00,  5.90s/it]
# repetition:  7
# 100%|██████████| 50/50 [04:46<00:00,  5.72s/it]
# repetition:  8
# 100%|██████████| 50/50 [04:43<00:00,  5.68s/it]
# repetition:  9
# 100%|██████████| 50/50 [04:35<00:00,  5.51s/it]
# Matyas_f
# repetition:  0
# repetition:  1
# repetition:  2
# repetition:  3
# repetition:  4
# repetition:  5
# repetition:  6
# repetition:  7
# repetition:  8
# repetition:  9
# Matyas_f
# repetition:  0
# repetition:  1
# repetition:  2
# repetition:  3
# repetition:  4
# repetition:  5
# repetition:  6
# repetition:  7
# repetition:  8
# repetition:  9
# Matyas_f
# repetition:  0
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879953039903
# TR update: iteration 2, objective 0.198, evaluation 13
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 0.09210214252728877
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.04077994774916616
# TR update: iteration 4, objective 0.041, evaluation 19
# 0.023218178179696125
# TR update: iteration 6, objective 0.023, evaluation 23
# 0.019871416181163087
# TR update: iteration 8, objective 0.020, evaluation 27
# 0.018279866715979365
# TR update: iteration 9, objective 0.018, evaluation 29
# 0.017671877308750722
# TR update: iteration 10, objective 0.018, evaluation 31
# 0.01740861118239967
# TR update: iteration 11, objective 0.017, evaluation 33
# 0.01720360017719047
# TR update: iteration 13, objective 0.017, evaluation 37
# 0.01714985903485086
# TR update: iteration 16, objective 0.017, evaluation 43
# 0.017101107651876807
# TR update: iteration 17, objective 0.017, evaluation 45
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\problems\problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# repetition:  1
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879908949838
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210211532149759
# TR update: iteration 3, objective 0.092, evaluation 15
# 0.057834860811379785
# TR update: iteration 4, objective 0.058, evaluation 19
# 0.03540640988567739
# TR update: iteration 5, objective 0.035, evaluation 22
# 0.020833259379550967
# TR update: iteration 8, objective 0.021, evaluation 29
# 0.019464546039985042
# TR update: iteration 13, objective 0.019, evaluation 39
# 0.017884843322696103
# TR update: iteration 14, objective 0.018, evaluation 41
# 0.017542873589929786
# TR update: iteration 17, objective 0.018, evaluation 47
# 0.017328096156178918
# TR update: iteration 18, objective 0.017, evaluation 49
# 0.017173422267274585
# TR update: iteration 20, objective 0.017, evaluation 53
# 0.017126483523197927
# TR update: iteration 22, objective 0.017, evaluation 57
# repetition:  2
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879945121792
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210210036587063
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.04407555880875824
# TR update: iteration 4, objective 0.044, evaluation 20
# 0.02965450025336014
# TR update: iteration 5, objective 0.030, evaluation 22
# 0.022145841464303373
# TR update: iteration 7, objective 0.022, evaluation 26
# 0.01939360518967187
# TR update: iteration 8, objective 0.019, evaluation 28
# 0.017654309373845323
# TR update: iteration 9, objective 0.018, evaluation 30
# 0.017347038240099755
# TR update: iteration 12, objective 0.017, evaluation 36
# 0.01719705951934175
# TR update: iteration 13, objective 0.017, evaluation 38
# 0.017122042999440007
# TR update: iteration 14, objective 0.017, evaluation 40
# 0.017117521103956646
# TR update: iteration 20, objective 0.017, evaluation 52
# 0.01711510154213816
# TR update: iteration 21, objective 0.017, evaluation 54
# 0.017113729462282484
# TR update: iteration 22, objective 0.017, evaluation 56
# repetition:  3
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879990069304
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210204481605744
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.04338471969398083
# TR update: iteration 4, objective 0.043, evaluation 19
# 0.02828114002572385
# TR update: iteration 5, objective 0.028, evaluation 21
# 0.021263404205897923
# TR update: iteration 8, objective 0.021, evaluation 27
# 0.018047886885144998
# TR update: iteration 9, objective 0.018, evaluation 29
# 0.01722086287661112
# TR update: iteration 12, objective 0.017, evaluation 35
# 0.017148978902678247
# TR update: iteration 16, objective 0.017, evaluation 43
# repetition:  4
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.1980187963654214
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210240427387051
# TR update: iteration 3, objective 0.092, evaluation 15
# 0.026263527475498538
# TR update: iteration 4, objective 0.026, evaluation 19
# 0.018997706972189915
# TR update: iteration 6, objective 0.019, evaluation 27
# 0.017954218968701585
# TR update: iteration 8, objective 0.018, evaluation 31
# 0.017490377359186127
# TR update: iteration 9, objective 0.017, evaluation 33
# 0.017236896927828843
# TR update: iteration 10, objective 0.017, evaluation 35
# 0.017188661889598916
# TR update: iteration 14, objective 0.017, evaluation 43
# 0.017175973123031235
# TR update: iteration 16, objective 0.017, evaluation 47
# 0.017169640076689585
# TR update: iteration 17, objective 0.017, evaluation 49
# 0.017168826122485242
# TR update: iteration 21, objective 0.017, evaluation 57
# repetition:  5
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879920186627
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210216428011675
# TR update: iteration 3, objective 0.092, evaluation 17
# 0.02626368420601749
# TR update: iteration 4, objective 0.026, evaluation 20
# 0.018602558799165725
# TR update: iteration 8, objective 0.019, evaluation 35
# 0.01800043456353284
# TR update: iteration 12, objective 0.018, evaluation 43
# 0.017481319353487124
# TR update: iteration 13, objective 0.017, evaluation 45
# 0.017248126215000326
# TR update: iteration 14, objective 0.017, evaluation 47
# 0.017133242436329077
# TR update: iteration 15, objective 0.017, evaluation 49
# 0.01711031009285638
# TR update: iteration 18, objective 0.017, evaluation 55
# repetition:  6
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879849579374
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210209296376926
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.044298302429680136
# TR update: iteration 4, objective 0.044, evaluation 19
# 0.020434275484202902
# TR update: iteration 5, objective 0.020, evaluation 21
# 0.01804200208436113
# TR update: iteration 14, objective 0.018, evaluation 49
# 0.01726334032507046
# TR update: iteration 16, objective 0.017, evaluation 53
# 0.017128253661005927
# TR update: iteration 17, objective 0.017, evaluation 55
# repetition:  7
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879948423817
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210214471111944
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.03934409199278521
# TR update: iteration 4, objective 0.039, evaluation 19
# 0.021427895958882254
# TR update: iteration 6, objective 0.021, evaluation 24
# 0.018324119203922573
# TR update: iteration 8, objective 0.018, evaluation 28
# 0.017391786474094117
# TR update: iteration 10, objective 0.017, evaluation 32
# 0.01716990371647284
# TR update: iteration 12, objective 0.017, evaluation 36
# 0.017160318781115125
# TR update: iteration 16, objective 0.017, evaluation 44
# 0.01715766278422068
# TR update: iteration 18, objective 0.017, evaluation 48
# 0.01715706316485016
# TR update: iteration 21, objective 0.017, evaluation 54
# repetition:  8
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879948418577
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210214383702331
# TR update: iteration 3, objective 0.092, evaluation 16
# 0.03845065705283712
# TR update: iteration 4, objective 0.038, evaluation 19
# 0.024709738027874906
# TR update: iteration 6, objective 0.025, evaluation 23
# 0.01963975737522583
# TR update: iteration 7, objective 0.020, evaluation 25
# 0.018182439915373355
# TR update: iteration 8, objective 0.018, evaluation 27
# 0.017549545899945812
# TR update: iteration 9, objective 0.018, evaluation 29
# 0.01729228420681711
# TR update: iteration 10, objective 0.017, evaluation 31
# 0.01723044032801757
# TR update: iteration 12, objective 0.017, evaluation 35
# 0.017188535658588716
# TR update: iteration 13, objective 0.017, evaluation 37
# 0.017136622063865375
# TR update: iteration 14, objective 0.017, evaluation 39
# 0.017115582056562828
# TR update: iteration 15, objective 0.017, evaluation 41
# 0.017105490990804995
# TR update: iteration 16, objective 0.017, evaluation 43
# 0.017100948836277247
# TR update: iteration 18, objective 0.017, evaluation 47
# repetition:  9
# 0.3500272619843434
# TR update: iteration 1, objective 0.350, evaluation 7
# 0.19801879903977682
# TR update: iteration 2, objective 0.198, evaluation 13
# 0.09210214471936862
# TR update: iteration 3, objective 0.092, evaluation 15
# 0.034986717024110714
# TR update: iteration 4, objective 0.035, evaluation 19
# 0.02261284030048588
# TR update: iteration 7, objective 0.023, evaluation 29
# 0.018966865303239405
# TR update: iteration 9, objective 0.019, evaluation 33
# 0.017942904167123935
# TR update: iteration 10, objective 0.018, evaluation 35
# 0.017383679824975073
# TR update: iteration 11, objective 0.017, evaluation 37
# 0.017221269490204028
# TR update: iteration 13, objective 0.017, evaluation 41
# 0.017180007088272442
# TR update: iteration 15, objective 0.017, evaluation 45
# 0.017159995985228882
# TR update: iteration 16, objective 0.017, evaluation 47
# 0.01714822614946468
# TR update: iteration 18, objective 0.017, evaluation 51
# 0.017138522205285056
# TR update: iteration 19, objective 0.017, evaluation 53
# 0.0171338301952981
# TR update: iteration 21, objective 0.017, evaluation 57
# Matyas_f
