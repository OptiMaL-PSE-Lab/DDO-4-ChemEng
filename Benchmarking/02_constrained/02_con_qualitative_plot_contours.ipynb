# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *

# %%
alg_list = [
    CBO_opt, # len_f = 92, len_g = 69, there are 11 starter points, for some reason in Matyas fkt nur 84
    CBO_TR_opt,
    COBYLA, # constrain evaluations are one more than function evaluations. The first 'none' in constraint evaluations has to be removed
    COBYQA, # constraint evaluations match function evaluations 
    opt_CUATRO # constraint evaluations match function evaluations 
]

N_x_ = 2                                                    # number of input dimensions

func_list = [
    'Rosenbrock_f',
    'Antonio_f',
    'Matyas_f',
]
i_rep = 0
track_x = True
# bounds_ = [[-5, 5],[-5, 5]] # x1 bounds, x2 bounds these are taken from the benchmarking routine
bounds_             = np.array([[-5,5] for i in range(N_x_)])
TR_plot       = False
x_shift_origin = np.array([[0],[0]]) # when wanting to not shift the objective function

# for alg_ in alg_list:
#     for func_ in func_list:
#         t_ = Test_function(func_, n_x=N_x_, track_x=track_x)
#         a, b, team_names, cids, X_opt_plot, TR_l, xnew, backtrck_l, samples_number = alg_(t_, N_x_, bounds_, f_eval_, i_rep)
#         ML4CE_con_contours(t_, alg_, bounds_, X_opt_plot, xnew, samples_number, func_, TR_plot, TR_l, SafeFig = False)

DataSave = False
directory_name = 'images/trajectory_plots_2D'

# %%
ML4CE_con_contour_allin1(func_list, alg_list, N_x_, x_shift_origin, bounds_, i_rep, bounds_plot=bounds_, directory_name=directory_name, SafeFig=DataSave)
# Out:
# Text saved to 'INFO' in folder 'images/trajectory_plots_2D'.
# <function CBO_opt at 0x000001B6FCB33380>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
#  23%|██▎       | 7/30 [00:04<00:16,  1.37it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 30/30 [01:44<00:00,  3.47s/it]
# ------------------------------------FINISH-----------------------------------------
# <function CBO_TR_opt at 0x000001B6ABED3C40>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 31/31 [01:46<00:00,  3.44s/it]
# ------------------------------------FINISH-----------------------------------------
# <function COBYLA at 0x000001B6ABBB98A0>
# len f_list COBYLA
# 40
# <function COBYQA at 0x000001B6ABED3CE0>
# <function opt_CUATRO at 0x000001B6ABED3E20>
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 487.0481651350755
# TR update: iteration 1, objective 487.048, evaluation 7
# 19.67913199554412
# TR update: iteration 2, objective 19.679, evaluation 12
# 19.0759979147502
# TR update: iteration 3, objective 19.076, evaluation 14
# 14.11617390674818
# TR update: iteration 6, objective 14.116, evaluation 20
# 13.855400619470954
# TR update: iteration 8, objective 13.855, evaluation 24
# 10.632422140588655
# TR update: iteration 9, objective 10.632, evaluation 26
# 9.068220114297686
# TR update: iteration 11, objective 9.068, evaluation 32
# TR update: iteration 14, objective 7.629, evaluation 38
# <function CBO_opt at 0x000001B6FCB33380>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 30/30 [01:37<00:00,  3.26s/it]
# ------------------------------------FINISH-----------------------------------------
# <function CBO_TR_opt at 0x000001B6ABED3C40>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
#   6%|▋         | 2/31 [00:01<00:20,  1.39it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 31/31 [01:40<00:00,  3.24s/it]
# ------------------------------------FINISH-----------------------------------------
# <function COBYLA at 0x000001B6ABBB98A0>
# len f_list COBYLA
# 40
# <function COBYQA at 0x000001B6ABED3CE0>
# <function opt_CUATRO at 0x000001B6ABED3E20>
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 169.17884735537223
# TR update: iteration 1, objective 169.179, evaluation 7
# 103.58157071189203
# TR update: iteration 2, objective 103.582, evaluation 13
# 54.293166117842915
# TR update: iteration 3, objective 54.293, evaluation 17
# TR update: iteration 4, objective 22.414, evaluation 20
# 5.627176030991778
# TR update: iteration 5, objective 5.627, evaluation 23
# TR update: iteration 8, objective 0.554, evaluation 34
# <function CBO_opt at 0x000001B6FCB33380>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
#  13%|█▎        | 4/30 [00:02<00:17,  1.45it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 30/30 [01:37<00:00,  3.23s/it]
# ------------------------------------FINISH-----------------------------------------
# <function CBO_TR_opt at 0x000001B6ABED3C40>
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 31/31 [01:41<00:00,  3.28s/it]
# ------------------------------------FINISH-----------------------------------------
# <function COBYLA at 0x000001B6ABBB98A0>
# len f_list COBYLA
# 40
# <function COBYQA at 0x000001B6ABED3CE0>
# <function opt_CUATRO at 0x000001B6ABED3E20>
# 0.43372615853066154
# TR update: iteration 1, objective 0.434, evaluation 7
# 0.2674524136522396
# TR update: iteration 2, objective 0.267, evaluation 12
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# 0.1411782957940435
# TR update: iteration 3, objective 0.141, evaluation 16
# 0.05490424269642802
# TR update: iteration 4, objective 0.055, evaluation 19
# 0.020701565791571702
# TR update: iteration 5, objective 0.021, evaluation 22
# 0.018238297029109285
# TR update: iteration 8, objective 0.018, evaluation 28
# 0.017877106149401162
# TR update: iteration 11, objective 0.018, evaluation 34
# 0.017710012592417473
# TR update: iteration 12, objective 0.018, evaluation 36
