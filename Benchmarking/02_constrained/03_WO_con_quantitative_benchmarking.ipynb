# %%
from WO import *
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from CUATRO import *

# %%
algorithms_test = [
    CBO_opt, 
    COBYLA, 
    COBYQA,
    opt_CUATRO
]

functions_test  = [
    'WO_f',
    ]

N_x_l        = [
    2,
    ]               # Number of input dimensions

reps         = 10

f_eval_l     = [
    20,
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

bounds  = np.array([[4., 7.], [70., 100.]])
home_dir  = 'images/WO/trajectory_plots_1D_&_tables'
SaveData = True

# %%
info, trajectories, timestamp = ML4CE_con_eval(N_x_l, f_eval_l, functions_test, algorithms_test, reps, home_dir, bounds=bounds, SafeData=SaveData)
# Out:
# Text saved to 'INFO' in folder 'images/WO/trajectory_plots_1D_&_tables'.
# im here
# =====================  WO_f D2
# ==  CBO_opt
#   0%|          | 0/10 [00:00<?, ?it/s]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\scipy\optimize\_optimize.py:404: RuntimeWarning: Values in x were outside bounds during a minimize step, clipping to bounds
#   warnings.warn("Values in x were outside bounds during a "
# 100%|██████████| 15/15 [00:27<00:00,  1.84s/it]
#  10%|█         | 1/10 [00:28<04:18, 28.67s/it]
# ------------------------------------FINISH-----------------------------------------
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:27<00:00,  1.86s/it]
# ------------------------------------FINISH-----------------------------------------
#  20%|██        | 2/10 [00:57<03:50, 28.87s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:30<00:00,  2.01s/it]
# ------------------------------------FINISH-----------------------------------------
#  30%|███       | 3/10 [01:28<03:29, 29.97s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:28<00:00,  1.87s/it]
# ------------------------------------FINISH-----------------------------------------
#  40%|████      | 4/10 [01:58<02:57, 29.64s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:26<00:00,  1.75s/it]
# ------------------------------------FINISH-----------------------------------------
#  50%|█████     | 5/10 [02:25<02:24, 28.89s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:27<00:00,  1.82s/it]
# ------------------------------------FINISH-----------------------------------------
#  60%|██████    | 6/10 [02:54<01:55, 28.79s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:27<00:00,  1.84s/it]
# ------------------------------------FINISH-----------------------------------------
#  70%|███████   | 7/10 [03:22<01:26, 28.72s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:32<00:00,  2.18s/it]
# ------------------------------------FINISH-----------------------------------------
#  80%|████████  | 8/10 [03:57<01:01, 30.61s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:29<00:00,  1.98s/it]
# ------------------------------------FINISH-----------------------------------------
#  90%|█████████ | 9/10 [04:28<00:30, 30.80s/it]
# - preliminar data supplied, computing objective and constraint values
# note: remember constraints are set as positive, so they should be set as -g(x)
# 100%|██████████| 15/15 [00:22<00:00,  1.50s/it]
# ------------------------------------FINISH-----------------------------------------
# 100%|██████████| 10/10 [04:52<00:00, 29.22s/it]
# ==  COBYLA
# 100%|██████████| 10/10 [00:04<00:00,  2.21it/s]
# ==  COBYQA
# 100%|██████████| 10/10 [00:06<00:00,  1.65it/s]
# ==  opt_CUATRO
#   0%|          | 0/10 [00:00<?, ?it/s]c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\reductions\solvers\solving_chain.py:235: UserWarning: You are solving a parameterized problem that is not DPP. Because the problem is not DPP, subsequent solves will not be faster than the first one. For more information, see the documentation on Disciplined Parametrized Programming, at https://www.cvxpy.org/tutorial/dpp/index.html
#   warnings.warn(DPP_ERROR_MSG)
# -2.908603466633622
# TR update: iteration 1, objective -2.909, evaluation 7
# c:\Users\mathi\.conda\envs\ddopt_2\Lib\site-packages\cvxpy\problems\problem.py:1407: UserWarning: Solution may be inaccurate. Try another solver, adjusting the solver settings, or solve with verbose=True for more information.
#   warnings.warn(
# -62.34697433205281
# TR update: iteration 2, objective -62.347, evaluation 13
#  10%|█         | 1/10 [00:01<00:12,  1.34s/it]
# 97.25003178760016
# TR update: iteration 1, objective 97.250, evaluation 7
#  20%|██        | 2/10 [00:02<00:11,  1.38s/it]
# 57.855902403166056
# TR update: iteration 1, objective 57.856, evaluation 7
#  30%|███       | 3/10 [00:04<00:09,  1.42s/it]
# 29.08067395064154
# TR update: iteration 1, objective 29.081, evaluation 7
# 7.116871669319039
# TR update: iteration 2, objective 7.117, evaluation 13
# -22.442363236845495
# TR update: iteration 3, objective -22.442, evaluation 17
#  40%|████      | 4/10 [00:05<00:09,  1.56s/it]
# -23.997535110317244
# TR update: iteration 1, objective -23.998, evaluation 7
# -73.15901991610997
# TR update: iteration 2, objective -73.159, evaluation 13
#  50%|█████     | 5/10 [00:07<00:07,  1.45s/it]
# -35.360772019294245
# TR update: iteration 1, objective -35.361, evaluation 7
#  70%|███████   | 7/10 [00:09<00:03,  1.24s/it]
# -9.292316119367456
# TR update: iteration 1, objective -9.292, evaluation 7
# -55.672771356405065
# TR update: iteration 3, objective -55.673, evaluation 16
#  80%|████████  | 8/10 [00:10<00:02,  1.25s/it]
# -36.72315290023084
# TR update: iteration 1, objective -36.723, evaluation 7
# -53.488382505750224
# TR update: iteration 3, objective -53.488, evaluation 15
#  90%|█████████ | 9/10 [00:12<00:01,  1.33s/it]
# -15.820743362419421
# TR update: iteration 1, objective -15.821, evaluation 7
# 100%|██████████| 10/10 [00:13<00:00,  1.36s/it]

# %% [markdown]
# ### Load Trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\Images\WO\trajectory_plots_1D_&_tables\2024-07-12_13-25-03\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-07-12_13-25-03'

# %%
test_res, vio_dict= ML4CE_con_table(trajectories, algorithms_test, functions_test, N_x_l)
# Out:
# ==   CBO_opt  ==
# ==   COBYLA  ==
# ==   COBYQA  ==
# ==   opt_CUATRO  ==

# %%
vio_dict
# Out:
# {'D2': {'CBO_opt': {'WO_f': {'vio_g': {'mean_vio': 0.010209215984896804,
#      'perc_nonvio': 92.85714285714286}}},
#   'COBYLA': {'WO_f': {'vio_g': {'mean_vio': 0.005248977726402672,
#      'perc_nonvio': 89.52380952380953}}},
#   'COBYQA': {'WO_f': {'vio_g': {'mean_vio': 0.006734918698270438,
#      'perc_nonvio': 86.25}}},
#   'opt_CUATRO': {'WO_f': {'vio_g': {'mean_vio': 0.013898299750024065,
#      'perc_nonvio': 83.84615384615385}}}}}

# %%
ML4CE_con_table_plot(test_res, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = SaveData)
# Out:
# The directory 'images/WO/trajectory_plots_1D_&_tables\2024-07-13_10-11-54\tables' does not exist in the root directory. Creating directory.

# %%
ML4CE_con_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=SaveData)
# Out:
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:505: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=3, label=str(i_alg.__name__), markersize = 10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:505: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=3, label=str(i_alg.__name__), markersize = 10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:505: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=3, label=str(i_alg.__name__), markersize = 10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:505: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=3, label=str(i_alg.__name__), markersize = 10)
# The directory 'images/WO/trajectory_plots_1D_&_tables\2024-07-13_10-11-54\trajectory_plots_1D' does not exist in the root directory.
