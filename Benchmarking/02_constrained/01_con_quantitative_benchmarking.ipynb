# %%
from BO import *
from COBYLA import *
from COBYQA import *
from utils import *
from test_function_constr import *
from ENTMOOT import *
from CUATRO import*

# %%
algorithms_test = [
    # CBO_opt,
    COBYLA,
    # COBYQA,
    # opt_CUATRO,
]

functions_test  = [
    'Rosenbrock_f',
    'Antonio_f',
    'Matyas_f',
    ]

N_x_l        = [
    2,
    ]               # Number of input dimensions

reps         = 1
f_eval_l     = [
    15,
    ]  # These are the number of function evaluations (length of trajectory) foreach run in reps. The number depends on the input dimension N_x_l

bounds_ = [[-7., 7.], [-7., 7.]]

home_dir  = 'images/trajectory_plots_1D_&_tables'
SaveData = True

# %%
info, trajectories, timestamp = ML4CE_con_eval(N_x_l, f_eval_l, functions_test, algorithms_test, reps, home_dir, SafeData=SaveData)
# Out:
# Text saved to 'INFO' in folder 'images/trajectory_plots_1D_&_tables'.
# =====================  Rosenbrock_f D2
# ==  COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 122.80it/s]
# =====================  Antonio_f D2
# ==  COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 190.82it/s]
# =====================  Matyas_f D2
# ==  COBYLA
# 100%|██████████| 1/1 [00:00<00:00, 334.31it/s]

# %% [markdown]
# ### Load trajectories

# %%
# import pickle

# # Open the file in binary mode for reading
# with open(r'C:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\Images\trajectory_plots_1D_&_tables\2024-07-13_10-07-52\trajectories.pkl', 'rb') as file:
#     # Load the object from the file
#     trajectories = pickle.load(file)

# # when loading data make sure to copy the folder name to get the timestamp
# timestamp = '2024-07-13_10-07-52'

# %% [markdown]
# ### Perform analyses

# %%
test_res, vio_dict= ML4CE_con_table(trajectories, algorithms_test, functions_test, N_x_l)
# Out:
# ==   COBYLA  ==
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:343: RuntimeWarning: invalid value encountered in divide
#   perf_ = ( (higall_[start_:] - trial_[start_:])

# %%
# this produces an error but still does the plot we want
# ML4CE_con_table_plot(test_res, functions_test, algorithms_test, N_x_l, home_dir, timestamp, SafeFig = SaveData)

# %%
ML4CE_con_graph_abs(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=SaveData)
# Out:
# The directory 'images/trajectory_plots_1D_&_tables\2024-08-08_16-28-30\trajectory_plots_1D' does not exist in the root directory.
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:543: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:543: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:543: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)

# %%
ML4CE_con_graph_abs_g(trajectories, algorithms_test, functions_test, N_x_l, home_dir, timestamp, SafeFig=SaveData)
# Out:
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:639: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:639: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)
# c:\Users\mathi\OneDrive\01_Studium\PhD\Projects\01_Book_Chapter\DDO-4-ChemEng\Benchmarking\02_constrained\utils.py:639: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "-o" (-> linestyle='-'). The keyword argument will take precedence.
#   plt.plot(trial_, '-o', color=color, linestyle=line_style, lw=4, label=str(i_alg.__name__), markersize=10)
